# %% [markdown]
# ## 1. Extracting Tags

# %% [markdown]
# ### 1.1. General Patterns: Extract tags from general_profiles_data.json

# %%
import json

# Load the JSON file
with open('general_profiles_data.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Extract tags, excluding 'N/A' values and usernames
filtered_tags = set()  # [] -> use .extend()
for details in data.values():
    tags = details.get('tags', [])
    filtered_tags.update(tag for tag in tags if tag != "N/A")

# Save tags to a new JSON file
with open('tags_in_general_profiles.json', 'w', encoding='utf-8') as file:
    json.dump(list(filtered_tags), file, indent=4)

print("Tags have been extracted and saved to 'tags_in_general_profiles.json'")

# Count unique tags
unique_tag_count = len(filtered_tags)
print(f"Total unique tags: {unique_tag_count}")
# Out:
# Tags have been extracted and saved to 'tags_in_general_profiles.json'
# Total unique tags: 2140

# %% [markdown]
# ### Community Patterns: Extract tags from profiles_by_comm_data.json

# %%
import json

# Load the JSON file
with open('profiles_by_comm_data.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Extract tags, excluding 'N/A' values and usernames
filtered_tags = set()
for comm in data.values():
    for details in comm.values():
        tags = details.get('tags', [])
        filtered_tags.update(tag for tag in tags if tag != "N/A")

# Save tags to a new JSON file
with open('tags_in_members_profiles.json', 'w', encoding='utf-8') as file:
    json.dump(list(filtered_tags), file, indent=4)

print("Tags have been extracted and saved to 'tags_in_members_profiles.json'")

# Count unique tags
unique_tag_count = len(filtered_tags)
print(f"Total unique tags: {unique_tag_count}")
# Out:
# Tags have been extracted and saved to 'tags_in_members_profiles.json'
# Total unique tags: 2767

# %% [markdown]
# ### 1.2. Merging into global list of unique tags

# %%
import json

# Load the first tags file
with open('tags_in_general_profiles.json', 'r', encoding='utf-8') as file:
    tags_general = json.load(file)

# Load the second tags file
with open('tags_in_members_profiles.json', 'r', encoding='utf-8') as file:
    tags_members = json.load(file)

# Merge the tags and remove duplicates
all_tags = set(tags_general + tags_members)

# Save the merged tags to a new JSON file
with open('all_tags.json', 'w', encoding='utf-8') as file:
    json.dump(list(all_tags), file, indent=4)

# Count unique tags
unique_tag_count = len(all_tags)
print(f"Total unique tags after merging: {unique_tag_count}")
# Out:
# Total unique tags after merging: 2965

# %% [markdown]
# ## 2. Word Embeddings & Tag Clustering:

# %% [markdown]
# ### 2.1. Word2Vec + K-Means

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\nastya\thesis\tum-thesis\gensim_env\Scripts\python.exe

# %%
# !python --version
# Out:
# Python 3.11.6

# %%
from gensim.models import Word2Vec
print("Gensim is working!")
# Out:
# Gensim is working!

# %%
import json
import re
import numpy as np
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from collections import defaultdict
from gensim.downloader import load

# Load tags from JSON file
with open('all_tags.json', 'r', encoding='utf-8') as file:
    tags = json.load(file)

# Preprocess tags (clean special characters, lowercase)
def preprocess_tag(tag):
    tag = re.sub(r'[^a-zA-Z0-9 ]', '', tag)  # Remove special characters
    return tag.lower()

tags = [preprocess_tag(tag) for tag in tags]

# Convert tags into Word2Vec-compatible format (list of lists)
tag_sentences = [[tag] for tag in tags]  # Each tag as a single word sentence

# Train Word2Vec model
w2v_model = Word2Vec(sentences=tag_sentences, vector_size=100, window=5, min_count=1, workers=4)
word_vectors = w2v_model.wv

# Generate tag embeddings
w2v_embeddings = np.array([word_vectors[tag] for tag in tags])

# Apply KMeans clustering
num_clusters = 30  # You can adjust this number
scaler = StandardScaler()
w2v_embeddings_scaled = scaler.fit_transform(w2v_embeddings)
kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
kmeans.fit(w2v_embeddings_scaled)
labels = kmeans.labels_

# Organize clusters
w2v_clusters = defaultdict(list)
for tag, label in zip(tags, labels):
    w2v_clusters[label].append(tag)

# Convert dictionary keys to strings before saving
w2v_clusters_str_keys = {str(k): v for k, v in w2v_clusters.items()}

# Save clusters
with open('word2vec_clusters.json', 'w', encoding='utf-8') as file:
    json.dump(w2v_clusters_str_keys, file, indent=4)

print("Word2Vec clustering completed. Clusters saved to 'word2vec_clusters.json'")
print(f"Total Word2Vec clusters: {len(w2v_clusters)}")

for cluster, cluster_tags in w2v_clusters.items():
    print(f"Cluster {cluster}: {cluster_tags}\n")
# Out:
# Word2Vec clustering completed. Clusters saved to 'word2vec_clusters.json'
# Total Word2Vec clusters: 30
# Cluster 3: ['alexander disease', 'severe asthma', 'normacol granules', 'linagliptin  metformin', 'adenomyosis', 'hip pain', 'myeloproliferative neoplasm mpn', 'brain tumours', 'burns and scalds', 'savella', 'alphagan eye drops', 'invega sustenna', 'urinary tract obstruction', 'lokelma', 'targinact', 'diamine oxidase', 'laminectomy', 'brain tumours lowgrademixed', 'metoprolol', 'inositol', 'phlebotomy', 'rheumatic fever', 'entacapone', 'mixtard', 'epididymitis', 'venofer', 'concerta', 'removab', 'rizatriptan', 'diltiazem', 'evra patch', 'neurontin', 'ipratropium', 'cystic fibrosis', 'acne', 'cerazette', 'prozac', 'dilantin', 'proton therapy', 'benepali', 'running', 'midodrine', 'acute renal failure', 'sst saliva stimulating', 'ibrutinib', 'c reactive protein test', 'matrifen transdermal patches', 'mst continus', 'phenytoin', 'epilepsy', 'myelopathy', 'afatinib', 'priadel', 'restasis eye drops', 'trigger finger', 'trulicity', 'hepatitis a vaccine', 'eye pain', 'adalimumab', 'swimming', 'solumedrol', 'nicorette', 'dental abscess', 'teriparatide', 'angina', 'olaparib', 'asthma', 'semaglutide', 'avelox', 'oxyal eye drops', 'kyleena', 'lacosamide', 'nebilet', 'bladder cancer', 'ventolin hfa', 'cod liver oil', 'wixela inhub', 'gaviscon', 'mezavant', 'rifaximin', 'plasma exchange', 'ovestin', 'sinemet', 'psychotherapy', 'diethylpropion', 'low mood', 'formoterol', 'nasonex', 'ovary removal', 'zirtek', 'silodyx', 'mitral valve disease', 'lexapro', 'metastasis', 'rifampin', 'antid', 'bloodcoagulation factor xiii', 'angioedema', 'anaphylaxis', 'microgynon', 'colpermin', 'embolisation', 'antisocial personality disorder', 'delamanid', 'respiratory tract infections rtis', 'acalabrutinib', 'richters syndrome', 'eplerenone', 'senna', 'neocytamen', 'genetic test']
#
# Cluster 1: ['azilect', 'small intestine bacterial overgrowth sibo', 'ofatumumab', 'nebulizer', 'constipation', 'low carb high fat lchf diet', 'hyaluronic acid', 'creatine kinase test ck', 'felodipine', 'dalfampridine', 'buprenorphine and naloxone', 'high blood pressure hypertension', 'elidel', 'brimonidine', 'obesity', 'calcium  vitamin d3', 'colofac', 'chromium', 'novorapid', 'wounds', 'musculoskeletal manipulations', 'skin or nail infections', 'penicillin v', 'papaverine', 'acute lymphoblastic leukaemia all', 'blood tests', 'vitamin k', 'reglan', 'high cholesterol', 'pentasa', 'fostair', 'levoxyl', 'cosopt eye drops', 'head pain', 'desvenlafaxine', 'mast cell activation syndrome mcas', 'schizophrenia', 'somatropin', 'fish oil', 'sativex', 'lorenzos oil', 'serc16', 'physostigmine', 'zinc', 'conditions and diseases', 'capasal therapeutic shampoo', 'maviret', 'nonhodgkin lymphoma', 'atopic eczema', 'cramp bark', 'amlodipine  olmesartan', 'tolvaptan', 'roaccutane', 'facial paresis', 'trelegy ellipta', 'predone', 'chronic lymphocytic leukemia cll', 'thyroid peroxidase tpo', 'spinal tap', 'dihydrocodeine', 'movicol', 'aphasia', 'eltrombopag', 'pituitary tumour', 'deep brain stimulation dbs', 'atovaquone', 'c3 glomerulopathy', 'anaemia', 'tidomat eye drops', 'barium test', 'trimethoprim', 'hepatitis', 'etrivex shampoo', 'levofloxacin', 'salpingectomy', 'pau darco', 'candesartan', 'varicose eczema', 'androcur', 'ldh test', 'catheterisation', 'lyrica', 'simvastatin  ezetimibe', 'eculizumab', 'ocaliva', 'carafate', 'antiphospholipid syndrome aps', 'donepezil', 'cialis', 'echocardiogram', 'deflazacort', 'sinemet cr', 'colchicine', 'betahistine', 'cervical screening', 'confidence in the care being received', 'piroxicam', 'diabetes', 'colcrys', 'canesten', 'liver disease', 'angioscopy', 'norgalax', 'hydrosalpinx', 'urinary tract tumours', 'rhinoplasty', 'alli', 'sofosbuvir']
#
# Cluster 14: ['lactase', 'bone health', 'floaters in the eyes', 'seizure', 'factor i test', 'linaclotide', 'carpal tunnel syndrome', 'ana test', 'tinnitus', 'tristatin', 'vascular surgery', 'levaquin', 'tadalafil', 'descovy', 'ulcerative colitis', 'frozen shoulder', 'tacrolimus', 'canabidiol cbd', 'temgesic', 'saw palmetto extract', 'endoxan', 'premenstrual dysphoric disorder pmdd', 'topical steroids', 'blepharitis', 'neurofeedback', 'mekinist', 'overactive thyroid hyperthyroidism', 'etodolac', 'coversyl', 'betaine hydrochloride', 'bronchiolitis', 'imfinzi', 'peptac liquid peppermint', 'gold thioglucose', 'azythromycin', 'remeron', 'buscopan', 'rigevidon', 'mohs surgery', 'genetic counseling', 'farxiga', 'fluorometholone', 'glomerulonephritis', 'baclofen', 'peak flow test', 'lysine', 'polyp removal', 'hydralazine  hydrochlorothiazide  reserpine', 'xaggitin xl', 'qvar', 'health anxiety', 'travoprost', 'liver transplant', 'music therapy', 'imitrex', 'etoposide', 'benzoyl peroxide', 'polymyositis', 'brain haemorrhage', 'neuropathies', 'myelofibrosis', 'handfootandmouth disease', 'adrenoleukodystrophy', 'postural drainage', 'endometrial ablation', 'perindopril', 'metronidazole', 'hypopituitarism', 'entecavir', 'mental health', 'diamine oxidase dao deficiency', 'chlorquinaldol  hydrocortisone', 'sildenafil', 'oesophageal cancer', 'nacetylcysteine nac', 'dexmethylphenidate', 'percutaneous coronary intervention pci', 'collagenous colitis', 'epoetin alfa', 'poisoning', 'surgery', 'capreomycin', 'tickborne encephalitis', 'alvesco', 'nasal and sinus cancer', 'whey protein', 'keytruda', 'polyp', 'paraffin', 'ferritin blood test', 'airomir', 'fungal infections', 'bypass surgery']
#
# Cluster 13: ['mens health', 'pancrelipase', 'hylocare eye drops', 'ofev', 'vitamin b12 deficiency', 'buccastem m', 'mastocytosis', 'fultiumd3', 'low carbohydrate diet', 'generalised anxiety disorder gad', 'tricuspid valve disease', 'unaspirin', 'tryptophan', 'optive eye drops', 'fentanyl', 'hypercalcaemia', 'naltrexone', 'hemiplegia', 'massage', 'incontinence sheaths', 'yoga', 'enzalutamide', 'salmeterol', 'nerve block', 'tenofovir  efavirenz  emtricitabine', 'natural thyroid', 'clotrimazole', 'telmisartan  amlodipine', 'iron sucrose', 'blisters', 'nasofan nasal spray', 'medrol', 'urologic surgery', 'spinal cord injuries', 'radioactive iodine', 'bells palsy', 'pariet', 'zydelig', 'watering eye', 'amino acids', 'cold therapy', 'tylenol', 'peritoneal dialysis', 'hypertrophic cardiomyopathy', 'levonorgestrel', 'support from familyfriends', 'clonidine', 'radical prostatectomy', 'lichen sclerosus', 'muscle pain', 'coal tar', 'synthroid', 'ivacaftor', 'medroxyprogesterone', 'gastrointestinal infections', 'pamidronate', 'meditation', 'tetrabenazine', 'ambien', 'glaucoma', 'opioids', 'intrauterine insemination iui', 'healthy living', 'esmya', 'namenda', 'nubeqa', 'heart attack', 'get active', 'multaq', 'aminophylline', 'nivolumab', 'cardiovascular disease cvd', 'ovarian cyst', 'eye conditions', 'iridectomy', 'granupas', 'pradaxa', 'hay fever', 'obinutuzumab', 'macrogol', 'cycling', 'cimetidine', 'piriton', 'theanine', 'nicotine addiction', 'thrombectomy', 'total ironbinding capacity tibc test', 'zolmitriptan', 'urecholine', 'slow sodium', 'double vision', 'minocycline', 'rheumatic heart disease', 'endoscopy gastrointestinal', 'soma', 'gilenya', 'iopidine eye drops', 'gazyvaro', 'turmeric extract', 'hemithyroidectomy', 'peyronies disease', 'bladder conditions', 'cysts', 'zofran odt', 'psoriasis', 'ureteroscopy', 'gastroscopy', 'natrilix', 'cyproheptadine', 'colectomy', 'meloxicam', 'calcichewd3']
#
# Cluster 27: ['diclofenac', 'laxatives', 'cerebral autosomal dominant arteriopathy with subcortical infarcts and leukoencephalopathy cadasil', 'calcipotriol', 'quetiapine', 'adrenal conditions', 'appendectomy', 'radiotherapy', 'gout', 'laryngitis', 'herbal medicines', 'psychiatric emergency services', 'inguinal hernia', 'lorazepam', 'perampanel', 'doxazosin', 'dovonex', 'sereflo', 'caesarean section', 'mucinex', 'digoxin specific antibody', 'mrsa', 'breast reconstruction', 'mestinon', 'ketamine', 'ventriculoperitoneal shunt', 'gallbladder removal', 'dermol cream', 'takotsubo cardiomyopathy', 'enbrel', 'hyperplasia', 'bezafibrate', 'tapentadol', 'beconase', 'heart transplant', 'major depressive disorder mdd', 'goserelin', 'immunosuppressants', 'lung transplant', 'gonadotrophin releasing hormone gnrh', 'urodol', 'discoid eczema', 'coarctation of the aorta', 'arthrotec', 'ramipril', 'talimogene laherparepvec', 'irritable hip', 'mirabegron', 'kratom', 'estradiol', 'persistent posturalperceptual dizziness', 'flunarizine', 'symbicort', 'cipralex', 'bed rest', 'advil', 'vitamin b9', 'prograf', 'rilpivirine', 'cladribine', 'cervical cancer', 'feeling anxious', 'solucortef', 'gemzar', 'tyrosine', 'kidney infection', 'vitamin b12  folic acid', 'agerelated cataracts', 'sirdupla', 'acea gel', 'creatine', 'urea topical', 'klonopin', 'pompholyx', 'poliomyelitis', 'back injury', 'itraconazole', 'narcolepsy', 'zyprexa', 'iron dextran', 'electrotherapy', 'dextrose', 'barretts oesophagus', 'eosinophilic disorders', 'phentermine', 'oxaliplatin', 'temporal arteritis giant cell arteritis', 'autoimmune diseases', 'low fat diet', 'laparotomy', 'birth defects', 'essential oils', 'dental caries', 'calcitriol', 'pervasive developmental disorders pdd', 'amlodipine', 'calcium carbonate', 'mortons neuroma', 'duoresp spiromax', 'mounjaro', 'h pylori', 'viagra', 'scleroderma', 'apremilast', 'flutamide', 'steroids', 'lubristil eye drops']
#
# Cluster 22: ['raynauds phenomenon', 'sexually transmitted infection sti', 'levothyroxine  liothyronine', 'amisulpride', 'refresh eye drops', 'lovastatin', 'zapain', 'mepolizumab', 'bradycardia', 'celluvisc eye drops', 'duaklir genuair', 'dofetilide', 'budesonide', 'financial concerns', 'cobalinh', 'sleep paralysis', 'glatiramer', 'insulin glargine', 'carbomer', 'flexeril', 'granulomatosis with polyangiitis', 'nintedanib', 'chantix', 'mobic', 'bile salts', 'cotrimoxazole', 'norgesic', 'trimbow', 'gastritis', 'eylea', 'aldomet', 'urethritis', 'peripheral artery disease', 'endocarditis', 'virus infections', 'letrozole', 'cornea transplant', 'bumetanide', 'cevimeline', 'ceftazidime intravenous infusion', 'cardiac arrest', 'congenital heart disease', 'lercanidipine', 'photodynamic therapy', 'saphris', 'achalasia', 'depakine', 'half betaprograne', 'enema', 'micardis', 'modified radical mastectomy', 'ethosuximide', 'ferrous fumarate', 'tildiem retard', 'lowdensity lipoprotein ldl', 'weightloss', 'eczema and dermatitis', 'adderall xr', 'receiving support from familyfriends', 'aproderm', 'garlic', 'artificial saliva', 'zytiga', 'femoston', 'serevent', 'linezolid', 'calorie restricted diet', 'pulmozyme', 'salagen', 'indoor allergy', 'adenoma', 'bovine thyroid', 'chest surgery', 'light therapy', 'cranberry extract', 'sodium valproate', 'counselling', 'vitamin e', 'neurofibromatosis type 2', 'encephalitis', 'type 2 diabetes', 'everolimus', 'intermittent catheterisation', 'orgovyx', 'lisinopril', 'intensity modulated radiation therapy imrt', 'mastectomy', 'metadate', 'parkinsonism', 'zovirax', 'ikervis', 'colchicine  probenecid', 'erfa thyroid', 'spina bifida', 'ankylosing spondylitis', 'bereavement', 'aversion therapy', 'joint replacement', 'heart failure', 'human papillomavirus hpv', 'general information about condition', 't3 test', 'dolutegravir', 'provenge', 'arrhythmia', 'exophthalmos bulging eyes', 'testogel', 'elleste duet', 'social anxiety', 'dutasteride', 'hydrochlorothiazide and lisinopril', 'carbocisteine', 'faslodex', 'amitiza', 'steroid injections', 'betacarotene', 'rheumatoid factor test', 'av atrioventricular node ablation', 'ultracet', 'pulmonary embolism', 'hydrocortisone  tretinoin  hydroquinone cream', 'tendon transfer', 'pancreatin', 'arginine  lysine', 'antihistamines']
#
# Cluster 17: ['zepatier', 'absent periods', 'clinical depression', 'flu', 'pertuzumab', 'vasculitis', 'truvada', 'sodium', 'feverfew', 'red clover', 'forsteo', 'collapsed lung', 'blood transfusion', 'florinef', 'cataract surgery', 'buccolam', 'arcoxia', 'perjeta', 'hibiscrub', 'supraventricular tachycardia svt', 'atenolol  nifedipine', 'fiorinal', 'enterectomy', 'humulin r', 'aortic valve disease', 'jaundice', 'nebido', 'interstitial cystitis', 'lacidipine', 'bendroflumethiazide', 'enzyme therapy', 'gentamicin', 'sclerotherapy', 'insulin aspart', 'elbow and arm pain', 'cetraben', 'tecentriq', 'mefenamic acid', 'dicyclomine', 'aqueous cream', 'tonsillitis', 'trigeminal neuralgia', 'immunodeficiencies and defective immune system', 'romosozumab', 'somatuline depot', 'muscular dystrophy', 'febuday', 'diverticulosis', 'coeliac disease', 'quinagolide', 'concussion', 'ceftazidime eye drops', 'revolade', 'arteritis', 'hair conditions', 'dianette', 'immunoglobulin m test', 'debulking surgery', 'goitre', 'oxycontin', 'in vitro fertilisation ivf', 'solifenacin', 'simply sleep', 'ipilimumab', 'breast cancer in men', 'liver resection', 'sleep apnoea', 'clomipramine', 'systane eye drops', 'prolactin test', 'cholestagel', 'olumiant', 'clostridium difficile infections', 'anal and rectal conditions', 'losec', 'hives', 'junel121', 'total hysterectomy', 'ethambutol', 'reclast', 'potassium hydroxide', 'sprains and strains', 'latanoprost', 'carbidopa', 'crizotinib', 'nexplanon', 'venesection', 'pulsed radiofrequency treatment', 'darbepoetin alfa']
#
# Cluster 20: ['spinal surgery', 'triamterene  hydrochlorothiazide', 'heart murmur', 'syphilis', 'upadacitinib', 'chronic leukaemia', 'nortriptyline', 'ajovy', 'histamine intolerance', 'imbruvica', 'primrose oil', 'nuvigil', 'mouth ulcers', 'antifungal medicines', 'alverine', 'multiple myeloma', 'sulfasalazine', 'angioplasty', 'heartburn and acid reflux', 'keppra', 'slipped disc', 'macushield', 'maxalt', 'vanishing white matter vwm disease', 'thymectomy', 'celebrex', 'bronchitis', 'physiotherapy', 'loratadine', 'latuda', 'imodium', 'brintellix', 'flucloxacillin', 'hypnotherapy', 'gastric bypass', 'underactive thyroid hypothyroidism', 'isoflavones', 'glutenfree diet', 'prolia', 'facial pain', 'stem cell and bone marrow transplants', 'tonsillectomy', 'telmisartan', 'buspirone', 'diarrhoea', 'cozaar', 'imjudo', 'autosomal dominant polycystic kidney disease adpkd', 'rilutek', 'tea tree oil', 'buprenorphine', 'stoma surgery', 'insulin', 'gm1 gangliosidosis', 'joint dislocations', 'movelat', 'pseudomyxoma peritonei pmp', 'pernicious anaemia', 'cymbalta', 'nitrolingual pumpspray', 'septra', 'guaifenesin', 'craniosynostosis', 'hydroxychloroquine', 'biologic therapy', 'hypromellose', 'first aid', 'simbrinza eye drops', 'developmental coordination disorder dyspraxia', 'kesimpta', 'mirapexin', 'pregnancy difficulties', 'tivicay', 'adderall', 'light compression bandage', 'harvoni', 'avonex', 'caelyx', 'heart block', 'penicillamine', 'birthmarks', 'linzess', 'dupixent', 'balanitis', 'mannitol', 'promethazine', 'viscotears', 'subarachnoid haemorrhage', 'azyter', 'azathioprine', 'ampyra', 'biperiden', 'minoxidil', 'polymyalgia rheumatica', 'preeclampsia', 'synarel nasal spray', 'jakafi', 'aclidinium', 'constella', 'levodopa  carbidopa  entacapone', 'postural orthostatic tachycardia syndrome pots', 'metabolic syndrome', 'prostap sr', 'prothionamide', 'lisdexamfetamine', 'access to care and support', 'epilim', 'testicle lumps and swellings', 'calcichew', 'joint pain']
#
# Cluster 16: ['systemic mastocytosis', 'calquence', 'tinzaparin', 'contraceptive injection', 'melatonin', 'transurethral resection of the prostate turp', 'levitra', 'bird flu', 'temodar', 'radium 223', 'traction', 'potassium chloride', 'kidney function test', 'provera', 'trodelvy', 'frontotemporal dementia', 'losartan', 'asbestosis', 'dabigatran', 'sulfacetamide', 'fludrocortisone', 'marevan', 'pelvic adhesions', 'nilandron', 'tramacet', 'tofacitinib', 'novolog', 'leg pain', 'stem cell mobilization', 'cogans syndrome', 'venetoclax', 'hydrotherapy', 'palexia', 'orencia', 'oesophagectomy', 'colposcopy', 'omentectomy', 'cycloserine', 'glimepiride', 'cetuximab', 'ponstan', 'glucose test', 'electroencephalogram eeg', 'coronary vasospastic disease', 'witch hazel', 'peginterferon alfa2b', 'methamphetamine', 'head and neck cancer', 'small cell lung cancer', 'neck dissection', 'provigil', 'biopsy', 'hydronephrosis', 'amoxicillin', 'sex hormone abnormalities', 'crinone progesterone vaginal', 'regaine extra strength', 'cardizem', 'procrit', 'persistent atrial fibrillation', 'entocort', 'adriamycin', 'rheumatoid arthritis', 'fluanxol', 'antipsychotics', 'ace inhibitors', 'bupramyl', 'retinal detachment', 'ciclesonide', 'oxybutynin', 'hyperglycaemia high blood sugar', 'antimullerian hormone test amh', 'rocephin', 'fedratinib', 'strontium89', 'contraception', 'hydrocortisone', 'agerelated macular degeneration amd', 'emollients', 'enalapril  hydrochlorothiazide', 'eliquis', 'zoloft', 'vabysmo', 'famotidine', 'ibandronic acid', 'paralysis', 'rosacea']
#
# Cluster 10: ['premenstrual syndrome pms', 'lung surgery', 'lazy eye', 'ranolazine', 'miscarriage', 'lacri lube eye drops', 'simponi', 'xopenex', 'sleep disorders', 'sage tincture', 'tetrahydrocannabinol thc', 'sertraline', 'rectocele', 'kava kava', 'vasodilators', 'noriday', 'kidney stones', 'abdominal hysterectomy', 'vascular conditions', 'pamsvax xl', 'repinex', 'betaprograne', 'sjogrens syndrome', 'medroxyprogesterone  oestrogen', 'xeljanz', 'home hemodialysis', 'intestinal and stomach conditions', 'fybogel', 'tenofovir', 'vagifem', 'fiasp', 'lax pills', 'resperal', 'accrete d3 tablets', 'cilazapril', 'epirubicin', 'urinary incontinence', 'eluxadoline', 'amiodarone', 'adrenocorticotropic hormone acth', 'octasa', 'migraleve', 'cosentyx', 'domestic violence', 'speech therapy', 'cavernoma', 'potassium citrate', 'pleural effusion', 'growth hormone abnormalities', 'aleve', 'piqray', 'leukaemia', 'niaspan', 'anagrelide', 'zoladex', 'diabetic nephropathy', 'eye movement desensitization and reprocessing emdr', 'calcium  magnesium', 'arrhythmogenic right ventricular cardiomyopathy arvc', 'cognitive behavioural therapy cbt', 'camptosar', 'lansoprazole', 'allegra', 'granuloma', 'conformal radiotherapy', 'tramazoline  dexamethasone', 'bentyl', 'fenofibrate', 'clomid', 'docusate', 'codeine', 'vidaza', 'occupational lung conditions', 'levbid', 'hepatitis b vaccine', 'paroxysmal atrial fibrillation', 'necrobiosis lipoidica', 'haemochromatosis', 'respiratory distress syndrome', 'estring vaginal ring', 'uveitis', 'chiropractic', 'diazepam', 'lustral', 'pelvic inflammatory disease pid', 'pepcid', 'acidophilus', 'kalms', 'dyskinesia', 'propylthiouracil', 'armour thyroid', 'complex regional pain syndrome', 'pneumonia', 'flolan', 'eating disorders', 'stretch marks', 'zoledronic acid', 'peripheral neuropathy', 'biomelatonin', 'bladder infections', 'afinitor']
#
# Cluster 12: ['nerve or brain infections', 'vaniqa cream', 'sutent', 'lipoedema', 'cutaneous mastocytosis', 'colostomy', 'wellbutrin', 'lumigan', 'carcinoembryonic antigen cea test', 'sodium picosulfate', 'toradol', 'barium swallow test', 'adapalene', 'mollarets meningitis', 'kidney diseases in childhood', 'zolpidem', 'microscopic polyangiitis', 'topiramate', 'factor x deficiency', 'kadcyla', 'oilatum', 'fludarabine cyclophosphamide and rituximab fcr', 'protopic', 'meclizine', 'risedronate', 'derma care hydrocortisone cream', 'perforated eardrum', 'chloral hydrate', 'joint fusion', 'zonisamide', 'neurodegenerative disease', 'duoneb', 'atorvastatin', 'venclexta', 'skin tags', 'thyroidstimulating hormone tsh test', 'lobectomy', 'fasenra', 'doxepin', 'megace', 'allergy test', 'vedolizumab', 'hydroxycarbamide', 'vardenafil', 'psychosis', 'nonsteroidal antiinflammatory drugs nsaids', 'intuniv', 'abiraterone', 'prevacid', 'inderal', 'ceftriaxone', 'animalassisted therapy', 'detrol', 'neutropenia', 'citalopram', 'rabeprazole', 'nicotinamide adenine dinucleotide nadh', 'discectomy', 'scolios
#
# Cluster 23: ['methylcobalamin', 'groin pain', 'eviplera', 'lipitor', 'luteinizing hormone lh test', 'hashimotos disease', 'cabergoline', 'tamoxifen', 'impetigo', 'asacol', 'ativan', 'parenting', 'immunoglobulin', 'zerobase', 'prazosin', 'rickets and osteomalacia', 'rotigotine', 'ialuril', 'hives and angioedema', 'vitamin d', 'cardiac resynchronization therapy', 'menstrual problems', 'nystatin', 'hp acthar gel', 'triglycerides management', 'chronic kidney disease ckd', 'lithium', 'liver failure', 'alopecia', 'gasx', 'lomustine', 'selenium', 'celecoxib', 'cystitis', 'bromocriptine', 'opicapone', 'clopidogrel', 'thyroid function test', 'tums', 'benazepril', 'uniphyllin continus', 'lactobacillus', 'hoarding disorder', 'coreg', 'linagliptin', 'cognitive impairment', 'transjugular intrahepatic portosystemic shunt tipss', 'cephalexin', 'imipramine', 'invega', 'immunodeficiency', 'stereotactic radiosurgery', 'lyme disease', 'carotid artery disease', 'brilique', 'pilonidal sinus', 'trelstar', 'coronary angioplasty and stent insertion', 'salbutamol', 'immunotherapy', 'verzenio', 'bile acid malabsorption', 'acetic acid', 'hormone replacement therapy hrt', 'estrogen replacement therapy', 'sigmoidoscopy', 'hyperthermia therapy', 'tildiem', 'oncobcg', 'kelp', 'tegretol', 'diclofenac sodium  misoprostol', 'ephedrine', 'butrans', 'xyrem', 'arimidex', 'urostomy', 'natural desiccated thyroid ndt', 'alverine  simeticone', 'larginine', 'optilast eye drops', 'heart valve annuloplasty', 'irbesartan', 'actavis levothyroxine']
#
# Cluster 5: ['pityriasis rosea', 'interferon', 'costochondritis', 'focalin', 'cyclobenzaprine', 't4 test', 'briviact', 'gallbladder cancer', 'vyvanse', 'locoid', 'tafinlar', 'polyhydramnios', 'arthritis', 'tazobactam', 'alcoholrelated liver disease arld', 'gallbladder and bile duct diseases', 'requip', 'esr test', 'entresto', 'focalin xr', 'celexa', 'cleft lip and palate', 'attia', 'salbutamol  ipratropium', 'valsartan  hydrochlorothiazide', 'biofreeze', 'verapamil', 'xofigo', 'pleurodesis', 'inflectra', 'eyedrops', 'nerve transfer', 'tiopex', 'epidural anesthesia', 'venous ulcer compression system', 'gemcitabine', 'probiotics', 'azarga eye drops', 'progressive supranuclear palsy psp', 'computerassisted radiation therapy', 'brivaracetam', 'cytomel', 'ocrevus', 'kyphosis', 'ulcers', 'juvenile idiopathic arthritis', 'eklira genuair', 'xarelto', 'necrosis', 'lupus', 'chest infection', 'clindamycin  benzoyl peroxide', 'brachytherapy', 'fleet glycerin suppositories', 'augmentin', 'lung disease', 'ritonavir', 'clarithromycin', 'alprazolam', 'transient ischaemic attack tia', 'dimenhydrinate', 'tirosint', 'sinusitis sinus infection', 'cholesterol management', 'salvage therapy', 'gastrooesophageal reflux disease', 'interferon beta1a', 'buspar', 'tylex', 'aerius', 'sucralfate', 'penicillin g', 'creon', 'orthostatic hypotension', 'chronic pain', 'continuous positive airway pressure cpap', 'temozolomide', 'xifaxan', 'extracorporeal membrane oxygenation ecmo', 'obliterative bronchiolitis', 'electroconvulsive therapy ect', 'group b strep', 'female infertility', 'rosuvastatin', 'endometriosis']
#
# Cluster 19: ['antacids', 'audavate', 'hearing tests', 'isotretinoin', 'indapamide', 'prilosec', 'acupuncture', 'capecitabine', 'cerebral autosomal recessive arteriopathy with subcortical infarcts and leukoencephalopathy carasil', 'ultrasound therapy', 'rybelsus', 'noradrenaline', 'zonegran', 'dapagliflozin  metformin', 'bipolar disorder', 'bisoprolol', 'darzalex', 'medikinet', 'peppermint oil', 'defibrillation', 'head injuries', 'vitrectomy', 'pemetrexed', 'leg or foot ulcers', 'caverject', 'desmopressin', 'mavenclad', 'urinary tract conditions', 'trimipramine', 'zemtard', 'play therapy', 'idiopathic thrombocytopenic purpura itp', 'trifluoperazine', 'azacitidine', 'nolvadex', 'pentoxifylline', 'personality disorder', 'water retention', 'hysteroscopy', 'corlanor', 'dementia with lewy bodies', 'heat exhaustion and heatstroke', 'binge eating', 'remedeine', 'galantamine', 'nifedipine', 'circadin', 'neck pain', 'adcald3', 'sulfazine', 'nplate', 'docetaxel', 'clenil modulite', 'hernia', 'pituitary problems', 'stalevo', 'vensir xl', 'elocon', 'salamol', 'deep vein thrombosis dvt', 'flurazepam', 'thyroiditis', 'borderline personality disorder', 'cipro', 'nucala', 'propranolol', 'olmesartan', 'ergotamine', 'catheter ablation', 'nalcrom', 'pregnancy test', 'chlorphenamine', 'obsessivecompulsive disorder ocd', 'fsh test', 'wockhardt levothyroxine', 'cortisone', 'sitagliptin', 'chondroitin', 'high fiber food', 'copaxone', 'tecfidera', 'lecithin', 'bundle branch block', 'rinvoq', 'coracten', 'urinary retention', 'trabeculectomy', 'flaxseed oil', 'investigational treatment', 'weight loss surgery', 'behcets disease', 'body dysmorphic disorder', 'clinitas eye drops', 'womb cancer', 'monopost eye drops', 'gastroparesis', 'voltarol', 'leukeran']
#
# Cluster 24: ['antiviral treatment', 'fioricet', 'kidney donation', 'zinc sulfate', 'palbociclib', 'acute myeloid leukaemia aml', 'leucovorin', 'zometa', 'learning disabilities', 'solumedrone', 'dehydroepiandrosterone dhea', 'excessive vomiting in pregnancy', 'insulin glulisine', 'isosorbide mononitrate', 'serrapeptase', 'adrenal cortex extract ace', 'ostomy belt', 'ebv infections', 'mouth throat and dental infections', 'latanoprost  timolol', 'polycystic ovary syndrome pcos', 'labyrinthitis', 'cyclosporin', 'cervical spondylosis', 'skin cancer', 'hiatus hernia', 'quinine', 'zomig', 'simvastatin', 'calcium', 'aortic valve replacement', 'regular insulin', 'aloe vera', 'milk thistle', 'mental disorder', 'insulin resistance', 'kisqali', 'permanent atrial fibrillation', 'acetazolamide', 'healthyeating', 'cisplatin', 'nilotinib', 'nasacort', 'azelaic acid', 'tubal sterilisation', 'romiplostim', 'partial thyroidectomy', 'appendix cancer', 'cytoxan', 'xanax', 'h
', 'panic disorder and panic attacks', 'cosmocol', 'empagliflozin  metformin', 'desiccated thyroid extract', 'levodopa', 'club foot', 'thyroid abnormalities', 'nexium', 'flomax', 'krill oil', 'decompressive craniectomy', 'brugada syndrome', 'autologous stem cell transplant', 'alphosyl', 'brittle asthma', 'nicardipine', 'cryosurgery', 'myrbetriq', 'levsin', 'prostatitis', 'alogliptin  metformin', 'migraine', 'taclonex', 'reboxetine', 'spironolactone', 'osteopenia', 'ventricular tachycardia', 'pegasys', 'questran', 'paroxetine', 'pessary', 'duodenitis', 'glutathione', 'deep heat', 'amlodipine  valsartan', 'whooping cough', 'diabetic neuropathy', 'adrenomyeloneuropathy', 'mezolar matrix transdermal patches', 'codydramol']
#
# Cluster 28: ['haldol', 'pregabalin', 'pancreas transplant', 'aplastic anaemia', 'chemotherapy', 'venlalic xl', 'mycophenolate', 'tranexamic acid', 'ribavirin', 'dyskeratosis congenita', 'multiple sclerosis', 'penis implant', 'tendonitis', 'insulin regular', 'atrioventricular av heart block', 'decapeptyl sr', 'epoetin zeta', 'vicodin', 'aubagio', 'alendronic acid  colecalciferol', 'clioquinol', 'ganfort eye drops', 'prostate disease', 'procarbazine', 'remsima', 'bunions', 'zofran', 'medication monitoring', 'nizoral', 'clorazepate', 'atarax', 'toprol', 'prolapse of the uterus', 'modopar', 'plantar fasciitis', 'trajenta', 'dimethyl fumarate', 'dichlorobenzyl alcohol', 'plastic surgery', 'taxol', 'carnitine', 'salicylic acid', 'digoxin', 'flixotide', 'tazocin', 'primary biliary cholangitis pbc', 'bicalutamide', 'campral', 'nephrotic syndrome', 'excedrin', 'skin graft', 'norethisterone', 'pleurisy', 'sotacor', 'triamcinolone acetonide', 'luteinizing hormone releasing hormone lhrh agonist', 'osteopathy', 'slophyllin', 'bone cancer', 'chest x ray', 'pain', 'thyroid cancer', 'imodium ad', 'sjogrenlarsson syndrome', 'naramig', 'enteritis', 'parathyroid conditions', 'primary ciliary dyskinesia pcd', 'cancer and tumours', 'warfarin', 'nicorandil', 'levothyroxine', 'colonoscopy', 'cellcept', 'tetanus', 'sevredol', 'neupro', 'bisoprolol  hydrochlorothiazide', 'sotalol', 'acid reflux']
#
# Cluster 26: ['prochlorperazine', 'regurin', 'seretide', 'intravenous immunoglobulin ivig', 'predalone 50', 'food allergy', 'certolizumab pegol', 'acute leukaemia', 'requip xl', 'overactive bladder', 'seasonal affective disorder sad', 'sarilumab', 'actonel', 'librax', 'diprobase', 'connective tissue diseases', 'questran light', 'pelvic organ prolapse', 'bion tears', 'indocid', 'modafinil', 'pneumonectomy', 'quitsmoking', 'gastrectomy', 'orlistat', 'estradiol  norethisterone', 'eltroxin', 'duloxetine', 'complex b', 'oesophagitis', 'vortioxetine', 'pioglitazone', 'epogen', 'ventolin', 'fluticasone', 'butchers broom', 'dementia', 'betamethasone  neomycin', 'amfetamine', 'gedarel', 'chlorambucil', 'dilaudid', 'tissue graft', 'pancreatitis', 'isoniazid', 'alfuzosin', 'otomize ear spray', 'fluticas
 'lenvatinib', 'paranoia', 'blood ketone test', 'sarcoidosis', 'methotrexate', 'heavy periods', 'clobetasol', 'sicklecell anaemia', 'vulval cancer', 'orchidectomy', 'puva therapy psoralen and ultraviolet a', 'umbilical hernia', 'bursitis', 'welchol', 'oedema', 'bile duct cancer', 'rozex', 'wellbutrin xl', 'oestrogel', 'emphysema', 'tezspire', 'lynch syndrome', 'zyrtec', 'imatinib', 'diabetic retinopathy', 'fluconazole', 'anoro ellipta', 'aricept', 'epanutin', 'ear conditions', 'forxiga', 'gallstones', 'joint hypermobility syndrome', 'varicose veins', 'flecainide', 'breo ellipta', 'alendronic acid', 'lithium carbonate', 'bedwetting', 'low sodium diet', 'gilberts syndrome', 'vascular dementia', 'kaolin', 'interstitial lung disease ild', 'lynparza', 'excoriation skin picking disorder', 'licorice extract', 'singulair', 'biofeedback therapy', 'guanfacine', 'ocrelizumab', 'fludarabine', 'azelastine', 'adizem', 'lucentis', 'nifedipress', 'acoustic neuroma', 'differin', 'xyzal', 'theophylline', 'menieres disease', 'bisacodyl', 'small lymphocytic lymphoma sll', 'humulin i', 'hydrocodone', 'cambia', 'radical hysterectomy', 'cyclopenthiazide', 'skyrizi', 'vaginal cancer', 'whiplash', 'nervous breakdown', 'tamsulosin  dutasteride', 'gastroenteritis', 'epclusa']
#
# Cluster 0: ['electric defibrillation', 'fluoxetine', 'adcal', 'hydroxyzine', 'vitamin c', 'atomoxetine', 'salazopyrin', 'coronary artery spasm', 'dexilant', 'cetirizine', 'nontuberculous mycobacterium', 'alanine transaminase test alt', 'taurine', 'reactive arthritis', 'probanthine', 'knee pain', 'phentolamine', 'apixaban', 'sonata', 'roactemra', 'cataflam', 'feeling lonely', 'depomedrone', 'lupron', 'attention deficit hyperactivity disorder adhd', 'sominex', 'oral chemotherapy', 'penile cancer', 'yervoy', 'atacand', 'thalidomide', 'ironorm', 'epoch chemotherapy', 'tysabri', 'carer support', 'hip replacement', 'magnesium sulphate', 'genital herpes', 'urine test', 'cyclogest', 'atezolizumab']
#
# Cluster 8: ['promazine', 'epaderm cream', 'sirolimus', 'nuvaring', 'heart bypass', 'agoraphobia', 'cilest', 'lialda', 'coumadin', 'meptazinol', 'amiloride  furosemide', 'gene therapy', 'colour vision deficiency', 'pericarditis', 'myomectomy', 'transcutaneous electrical nerve stimulation tens', 'urticarial vasculitis', 'nitrofurantoin', 'clotrimazole  fluconazole', 'lymphocytic leukemia', 'atherosclerosis', 'urinary tract stones', 'stressless herbal tablets', 'methimazole', 'ibuleve', 'atripla', 'ibuprofen', 'emsam', 'heart valve diseases', 'tibolone', 'speech problems', 'breztri aerosphere', 'sciatica', 'chloroquine', 'multivitamins', 'magnesium citrate', 'alzheimers disease', 'sports injuries', 'carvedilol', 'promacta', 'breast tumours', 'myasthenia gravis', 'lotronex', 'antipressan', 'gingivitis and periodontitis', 'alprostadil', 'daytrana', 'pramoxine', 'parenteral nutrition', 'risperdal', 'coronary heart disease', 'beckwithwiedemann syndrome', 'idelalisib', 'anastrozole', 'nuedexta', 'metabolic conditions', 'clinical trials', 'ketosis', 'streptococcal infections', 'avodart', 'nodular prurigo', 'lithotripsy', 'neomycin  prednisolone', 'sti test', 'partial mastectomy', 'alomide eye drops', 'chemydur 60xl', 'quit smoking', 'dulera', 'cysteine', 'periodic limb movement disorder', 'primary progressive multiple sclerosis', 'porphyria', 'chlamydia', 'shingles vaccine', 'oxygen therapy', 'cyramza', 'lovenox', 'colitis', 'male infertility', 'relpax', 'sumatriptan', 'horizant', 'anafranil', 'hydrocortisone topical', 'incruse ellipta', 'pluvicto', 'thealoz duo eye drops', 'ventricular fibrillation', 'rape and sexual assault', 'gender dysphoria', 'crohns disease', 'fingolimod', 'cryotherapy']
#
# Cluster 7: ['oxycodone', 'irinotecan', 'lipoic acid', 'besremi', 'menopause', 'efudix cream', 'irregular periods', 'zydol', 'mouth sore', 'brukinsa', 'lisinopril  hydrochlorothiazide', 'alcohol misuse', 'eligard', 'aneurysm', 'salivix', 'pelvic floor dysfunction', 'neurofibromatosis type 1', 'mirapex', 'back pain', 'lofepramine', 'spinal manipulation', 'alimta', 'traxam pain relief', 'theicald3', 'eye cancer', 'triumeq', 'acupressure', 'belimumab', 'parathyroid hormone pth', 'brinzolamide  brimonidine', 'cystoscopy', 'botox', 'amyotrophic lateral sclerosis als', 'lymph node removal', 'sleep hygiene', 'bupropion', 'mirena', 'trileptal', 'foetal alcohol spectrum disorders fasd', 'hydrea', 'noonan syndrome', 'fentalis reservoir transdermal patches', 'vitamin b6', 'desogestrel', 'atrial flutter', 'tooth extraction', 'hypotonia', 'quinidine', 'raloxifene', 'cimzia', 'lung cancer', 'cerebral vasculitis', 'suboxone', 'elleste solo', 'primidone', 'aromatherapy', 'fragmin', 'vulvodynia', 'ferinject', 'hepatitis b', 'diabetes diet', 'colesevelam', 'neurological conditions', 'altitude sickness', 'pregnenolone', 'chlorpromazine', 'fluvoxamine', 'sleepwalking', 'carbamazepine', 'oesophageal conditions', 'idiopathic pulmonary fibrosis ipf', 'mesalazine', 'obeticholic acid', 'aminosalicylic acid', 'passion flower', 'atenolol  bendroflumethiazide', 'flixonase', 'tetracycline', 'parathyroidectomy', 'seroxat', 'iron', 'euthyrox', 'appendicitis', 'arnica', 'tilade']
#
# Cluster 4: ['autosomal recessive polycystic kidney disease arpkd', 'atenolol', 'urso', 'circumcision', 'tenofovir  emtricitabine  rilpivirine', 'allopurinol', 'streptomycin', 'effexor', 'amputation', 'viibryd', 'auditory stimulation', 'metformin', 'ear infections', 'trihexyphenidyl', 'oramorph', 'diabetes insipidus', 'antivascular endothelial growth factor antivegf', 'actos', 'hiprex', 'revlimid', 'temazepam', 'weight loss', 'breast cancer metastatic', 'prediabetes', 'vaginal ring', 'halaven', 'oracea', 'guillainbarre syndrome', 'phenergan', 'naratriptan', 'zocor', 'thyroid conditions', 'humira', 'alteplase', 'phorpain', 'zomorph', 'opdivo', 'estradot patches', 'oestrogen', 'prediabetes', 'memantine', 'lopressor', 'tobramycin',
# %% [markdown]
# ### 2.2. GloVe + K-Means

# %%
import json
import re
import numpy as np
from gensim.models import KeyedVectors
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from collections import defaultdict
from gensim.downloader import load

# Load tags from JSON file
with open('all_tags.json', 'r', encoding='utf-8') as file:
    tags = json.load(file)

# Preprocess tags (clean special characters, lowercase)
def preprocess_tag(tag):
    tag = re.sub(r'[^a-zA-Z0-9 ]', '', tag)  # Remove special characters
    return tag.lower()

tags = [preprocess_tag(tag) for tag in tags]

# Load pre-trained GloVe model
glove_model = load("glove-wiki-gigaword-100")  # 100-dimensional GloVe vectors

# Generate GloVe embeddings
glove_embeddings = []
valid_tags = []
for tag in tags:
    if tag in glove_model:
        glove_embeddings.append(glove_model[tag])
        valid_tags.append(tag)  # Keep only tags that exist in GloVe

glove_embeddings = np.array(glove_embeddings)

# Apply KMeans clustering to GloVe embeddings
num_clusters = 20  # You can adjust this number
scaler = StandardScaler()
glove_embeddings_scaled = scaler.fit_transform(glove_embeddings)
kmeans_glove = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
kmeans_glove.fit(glove_embeddings_scaled)
glove_labels = kmeans_glove.labels_

# Organize clusters
glove_clusters = defaultdict(list)
for tag, label in zip(valid_tags, glove_labels):
    glove_clusters[label].append(tag)

# Convert dictionary keys to strings before saving
glove_clusters_str_keys = {str(k): v for k, v in glove_clusters.items()}

# Save clusters
with open('glove_clusters.json', 'w', encoding='utf-8') as file:
    json.dump(glove_clusters_str_keys, file, indent=4)

print("GloVe clustering completed. Clusters saved to 'glove_clusters.json'")
print("GloVe Clusters:")
for cluster, cluster_tags in glove_clusters.items():
    print(f"Cluster {cluster}: {cluster_tags}\n")
# Out:
# GloVe clustering completed. Clusters saved to 'glove_clusters.json'
# GloVe Clusters:
# Cluster 3: ['lactase', 'saline', 'progesterone', 'melatonin', 'seizure', 'dopamine', 'tryptophan', 'noradrenaline', 'immunoglobulin', 'inositol', 'taurine', 'testosterone', 'oestrogen', 'isoflavones', 'lycopene', 'estradiol', 'carnitine', 'insulin', 'methamphetamine', 'garlic', 'lysine', 'tyrosine', 'adenosine', 'collagen', 'creatine', 'kelp', 'kaolin', 'glutamine', 'cysteine', 'dextrose', 'ginseng', 'ephedrine', 'haemoglobin', 'niacin', 'mannitol', 'heparin', 'lecithin', 'glutathione', 'nicotinamide', 'adrenaline', 'steroids', 'biotin']
#
', 'detrol', 'citalopram', 'trileptal', 'dilaudid', 'kratom', 'remeron', 'adalimumab', 'alprostadil', 'medroxyprogesterone', 'sorafenib', 'imipramine', 'mebendazole', 'esomeprazole', 'psyllium', 'niaspan', 'omeprazole', 'berberine', 'galantamine', 'quinidine', 'xeloda', 'nifedipine', 'sominex', 'enoxaparin', 'selegiline', 'dihydrocodeine', 'cladribine', 'guaifenesin', 'suboxone', 'anastrozole', 'enalapril', 'boniva', 'procardia', 'primidone', 'ezetimibe', 'intal', 'hyoscyamine', 'trimethoprim', 'pethidine', 'ondansetron', 'epipen', 'etoposide', 'hydroxyurea', 'levofloxacin', 'ipilimumab', 'strattera', 'klonopin', 'ergotamine', 'norco', 'clomid', 'candesartan', 'adriamycin', 'lisinopril', 'pregnenolone', 'cryosurgery', 'fluvoxamine', 'hydromorphone', 'clomipramine', 'capsicum', 'tegretol', 'perindopril', 'anakinra', 'creon', 'eculizumab', 'theanine', 'subutex', 'spironolactone', 'etanercept', 'quercetin', 'dextroamphetamine', 'oxaliplatin', 'neomycin', 'carboplatin', 'donepezil', 'promethazine', 'pegasys', 'xyrem', 'colace', 'sumatriptan', 'levothyroxine', 'aripiprazole', 'pyrazinamide', 'temozolomide', 'hydralazine', 'pantoprazole', 'lactulose', 'rocephin', 'acidophilus', 'calcitriol', 'kalms', 'ethambutol', 'dutasteride', 'amlodipine', 'femara', 'aciclovir', 'ubiquinol', 'arnica', 'carbidopa', 'exemestane', 'irbesartan', 'inulin', 'doxylamine', 'emollients', 'mirtazapine', 'geodon', 'rosuvastatin', 'diamox', 'estriol', 'alli']
#
# Cluster 8: ['vertebroplasty', 'nebulizer', 'colostomy', 'nephrectomy', 'phlebotomy', 'myomectomy', 'lobectomy', 'gastrectomy', 'defibrillation', 'acupressure', 'eyedrops', 'hypnotherapy', 'vitrectomy', 'craniotomy', 'neurofeedback', 'sclerotherapy', 'cystoscopy', 'tonsillectomy', 'hydrotherapy', 'colposcopy', 'tracheostomy', 'thyroidectomy', 'discectomy', 'enema', 'prostatectomy', 'haemodialysis', 'brachytherapy', 'immunotherapy', 'splenectomy', 'sigmoidoscopy', 'lithotripsy', 'sleepwalking', 'electrotherapy', 'cardioversion', 'arthroscopy', 'imap', 'laparoscopy', 'echocardiogram', 'laparotomy', 'endoscopy', 'osteotomy', 'gastroscopy', 'rhinoplasty', 'cryotherapy']
#
# Cluster 15: ['interferon', 'prilosec', 'lipitor', 'tamoxifen', 'levitra', 'ribavirin', 'wellbutrin', 'actos', 'claritin', 'avastin', 'arcoxia', 'modafinil', 'enbrel', 'zocor', 'fosamax', 'botox', 'epogen', 'statins', 'taxol', 'raloxifene', 'thalidomide', 'tysabri', 'zyprexa', 'avonex', 'herceptin', 'phentermine', 'warfarin', 'cialis', 'plavix', 'viagra', 'crestor', 'aranesp']
#
# Cluster 13: ['phobias', 'anxiety', 'constipation', 'agoraphobia', 'traction', 'fatigue', 'claustrophobia', 'paranoia', 'stress', 'psychosis', 'vertigo', 'pain', 'narcolepsy', 'headaches', 'migraine', 'insomnia', 'addiction', 'dyslexia', 'whiplash']
#
# Cluster 11: ['oxycodone', 'lidocaine', 'fentanyl', 'vicodin', 'xanax', 'ambien', 'opioids', 'opiates', 'valium', 'oxycontin', 'morphine', 'percocet', 'codeine', 'benzodiazepines', 'cortisone', 'methadone', 'diazepam', 'ritalin', 'hydrocodone']
#
# Cluster 7: ['irinotecan', 'sutent', 'neoral', 'seretide', 'protonix', 'imigran', 'effexor', 'denosumab', 'revlimid', 'neupogen', 'celexa', 'chantix', 'rituxan', 'glucophage', 'neulasta', 'phenergan', 'zomig', 'norvasc', 'abilify', 'paclitaxel', 'humira', 'neurontin', 'yasmin', 'lantus', 'kaletra', 'pulmicort', 'toprol', 'cozaar', 'rituximab', 'carvedilol', 'prevacid', 'coreg', 'zantac', 'rilutek', 'nolvadex', 'lupron', 'synthroid', 'lotronex', 'symbicort', 'prasugrel', 'nicorette', 'risperdal', 'zoladex', 'cymbalta', 'advair', 'zyrtec', 'excedrin', 'provigil', 'docetaxel', 'camptosar', 'serevent', 'allegra', 'augmentin', 'aricept', 'xalatan', 'flonase', 'betaseron', 'gemzar', 'nexium', 'remicade', 'imitrex', 'humalog', 'diflucan', 'cardizem', 'procrit', 'xolair', 'taxotere', 'depakote', 'lamictal', 'buspar', 'singulair', 'nasonex', 'lyrica', 'zovirax', 'nexavar', 'lovenox', 'lexapro', 'lucentis', 'lunesta', 'copaxone', 'erbitux', 'losec', 'pepcid', 'arimidex', 'provenge', 'voltaren', 'velcade', 'topamax', 'seroxat', 'cellcept', 'rebif', 'forteo', 'seroquel', 'streptokinase']
#
# Cluster 1: ['malabsorption', 'mastocytosis', 'impetigo', 'vasculitis', 'bradycardia', 'vaginismus', 'hemiplegia', 'arava', 'epididymitis', 'dysthymia', 'prediabetes', 'aspergillosis', 'lymphomas', 'hyperplasia', 'bronchiectasis', 'myositis', 'urethritis', 'bunions', 'sonata', 'prediabetes', 'cystitis', 'synovitis', 'myelopathy', 'neuritis', 'bronchiolitis', 'oedema', 'neutropenia', 'achalasia', 'kyphosis', 'plagiocephaly', 'glomerulonephritis', 'leukodystrophy', 'hypotonia', 'diverticulosis', 'ataxia', 'hydronephrosis', 'arteritis', 'craniosynostosis', 'adenoma', 'granuloma', 'goitre', 'neurofibromatosis', 'ketosis', 'thyroiditis', 'polymyositis', 'neuropathies', 'pneumonitis', 'myelofibrosis', 'lymphadenopathy', 'adrenoleukodystrophy', 'glioblastoma', 'prostatitis', 'bedwetting', 'parkinsonism', 'haemochromatosis', 'porphyria', 'cellulitis', 'enteritis', 'hypopituitarism', 'hyperparathyroidism', 'dermatomyositis', 'osteopenia', 'uveitis', 'birthmarks', 'spasticity', 'meningioma', 'balanitis', 'phimosis', 'angioedema', 'dandelion', 'anaphylaxis', 'soma', 'ringworm', 'cambia', 'dyskinesia', 'myopathy', 'thalassaemia', 'gastroparesis']
#
# Cluster 6: ['chemotherapy', 'radiotherapy', 'angioplasty', 'lasik', 'dialysis', 'biopsy', 'lumpectomy', 'mastectomy', 'colonoscopy', 'surgery']
#
# Cluster 10: ['fibromyalgia', 'arthritis', 'obesity', 'osteoarthritis', 'acne', 'schizophrenia', 'dementia', 'epilepsy', 'ulcers', 'asthma', 'osteoporosis', 'diabetes', 'psoriasis', 'autism']
#
# Cluster 16: ['menopause', 'miscarriage', 'circumcision', 'hysterectomy', 'wounds', 'atherosclerosis', 'stroke', 'fertility', 'thrombosis', 'stillbirth', 'fibroids', 'fractures', 'anorexia', 'pregnancy', 'preeclampsia', 'contraception', 'cysts', 'endometriosis', 'scars', 'bulimia']
#
# Cluster 12: ['acupuncture', 'massage', 'physiotherapy', 'neurosurgery', 'osteopathy', 'aromatherapy', 'counselling', 'psychotherapy', 'naturopathy', 'chiropractic', 'homeopathy', 'bereavement']
#
# Cluster 19: ['syphilis', 'meningitis', 'flu', 'accidents', 'diarrhoea', 'antibiotics', 'hepatitis', 'encephalitis', 'mumps', 'chlamydia', 'allergies', 'herpes', 'poisoning', 'tetanus', 'pneumonia', 'gastroenteritis']
#
# Cluster 18: ['fibrosis', 'shingles', 'tinnitus', 'mrsa', 'asbestosis', 'retinitis', 'jaundice', 'blisters', 'sarcoidosis', 'alopecia', 'rhinitis', 'endocarditis', 'haemophilia', 'carcinoma', 'immunodeficiency', 'leukaemia', 'emphysema', 'glaucoma', 'necrosis', 'adenocarcinoma', 'lupus', 'aphasia', 'anaemia', 'vitiligo', 'sepsis', 'mesothelioma', 'poliomyelitis', 'melanoma', 'cataracts', 'metastasis', 'colitis', 'hives', 'nephritis', 'scleroderma', 'dystonia', 'polyp', 'retina', 'paralysis', 'rosacea']
#
# Cluster 2: ['fitness', 'fitness', 'parenting', 'running', 'swimming', 'cycling', 'exercise']
#
# Cluster 9: ['appendectomy', 'toothache', 'gout', 'amputation', 'laryngitis', 'aneurysm', 'pericarditis', 'tendonitis', 'bronchitis', 'gastritis', 'sciatica', 'cardiomyopathy', 'bursitis', 'myocarditis', 'tonsillitis', 'scoliosis', 'pancreatitis', 'hydrocephalus', 'astigmatism', 'angina', 'pacemaker', 'concussion', 'pleurisy', 'hernia', 'gallstones', 'tachycardia', 'arrhythmia', 'appendicitis']
#
# Cluster 17: ['sodium', 'chromium', 'calcium', 'lithium', 'iodine', 'selenium', 'zinc', 'vitamins', 'manganese', 'sulphur', 'iron', 'magnesium']
#
# Cluster 4: ['celebrex', 'antidepressants', 'ibuprofen', 'prozac', 'tylenol', 'aleve', 'advil', 'inhalers', 'cipro', 'aspirin', 'paxil', 'naproxen', 'zoloft', 'antihistamines']
#
# Cluster 14: ['yoga', 'meditation']

# %% [markdown]
# ### FastText + HDBSCAN

# %%
import json
import re
import numpy as np
from gensim.models import KeyedVectors
from sklearn.preprocessing import StandardScaler
from collections import defaultdict
import hdbscan
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from gensim.downloader import load
import pandas as pd

# Step 1: Load existing tags (adjust path if needed)
with open('all_tags.json', 'r', encoding='utf-8') as file:
    tags = json.load(file)

# Flatten all tags
# all_tags = []
# for tags in clusters.values():
#     all_tags.extend(tags)

# Step 2: Preprocess tags
def preprocess_tag(tag):
    tag = re.sub(r'[^a-zA-Z0-9 ]', '', tag)  # Remove special characters
    return tag.lower()

all_tags = [preprocess_tag(tag) for tag in tags]

# # Step 3: Load pre-trained FastText vectors (this may take some time to download first time)
# print("Loading FastText model...")
# fasttext_model = load('fasttext-wiki-news-subwords-300')

# # Step 4: Generate embeddings
# embeddings = []
# for tag in all_tags:
#     words = tag.split()
#     word_vectors = []
#     for word in words:
#         if word in fasttext_model:
#             word_vectors.append(fasttext_model[word])
#     if word_vectors:
#         avg_vector = np.mean(word_vectors, axis=0)
#         embeddings.append(avg_vector)
#     else:
#         embeddings.append(np.zeros(300))  # Unknown words fallback

# embeddings = np.array(embeddings)

# # Step 5: Standardize
# scaler = StandardScaler()
# embeddings_scaled = scaler.fit_transform(embeddings)

# # Step 6: HDBSCAN clustering
# print("Running HDBSCAN clustering...")
# clusterer = hdbscan.HDBSCAN(min_cluster_size=15, metric='euclidean')
# cluster_labels = clusterer.fit_predict(embeddings_scaled)

# # Step 7: Organize clusters
# hdbscan_clusters = defaultdict(list)
# for tag, label in zip(all_tags, cluster_labels):
#     if label != -1:  # Exclude noise points
#         hdbscan_clusters[label].append(tag)

# # Step 8: Print cluster summary
# print(f"Total clusters found (excluding noise): {len(hdbscan_clusters)}")
# for label, tags in hdbscan_clusters.items():
#     print(f"\nCluster {label} ({len(tags)} tags):")
#     print(tags[:10])  # Show first 10 tags per cluster

# # Step 9: Visualization with t-SNE
# print("Visualizing clusters...")
# tsne = TSNE(n_components=2, random_state=42, perplexity=30)
# tsne_result = tsne.fit_transform(embeddings_scaled)

# plt.figure(figsize=(12, 8))
# scatter = plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=[label if label != -1 else 99 for label in cluster_labels], cmap='tab20', alpha=0.7)
# plt.title('HDBSCAN Clustering of Health Tags (FastText Embeddings)')
# plt.xlabel('t-SNE Dim 1')
# plt.ylabel('t-SNE Dim 2')
# plt.colorbar(scatter, label='Cluster Label (-1 = Noise)')
# plt.show()

# %%
# Step 3: Load pre-trained FastText vectors (this may take some time to download first time)
print("Loading FastText model...")
fasttext_model = load('fasttext-wiki-news-subwords-300')
# Out:
# Loading FastText model...

# %%
# import umap

# Step 4: Generate embeddings
embeddings = []
for tag in all_tags:
    words = tag.split()
    word_vectors = []
    for word in words:
        if word in fasttext_model:
            word_vectors.append(fasttext_model[word])
    if word_vectors:
        avg_vector = np.mean(word_vectors, axis=0)
        embeddings.append(avg_vector)
    else:
        embeddings.append(np.zeros(300))  # Unknown words fallback

embeddings = np.array(embeddings)

# Step 5: Standardize
scaler = StandardScaler()
embeddings_scaled = scaler.fit_transform(embeddings)

# # Apply UMAP dimensionality reduction
# print("Running UMAP reduction...")
# reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, metric='euclidean', random_state=42)
# embeddings_umap = reducer.fit_transform(embeddings_scaled)

# Step 6: HDBSCAN clustering
print("Running HDBSCAN clustering...")
clusterer = hdbscan.HDBSCAN(min_cluster_size=5, metric='euclidean')  # 5-15 min_cluster
cluster_labels = clusterer.fit_predict(embeddings_scaled)

# Step 7: Organize clusters
hdbscan_clusters = defaultdict(list)
for tag, label in zip(all_tags, cluster_labels):
    if label != -1:  # Exclude noise points
        hdbscan_clusters[label].append(tag)

# Step 8: Print cluster summary
print(f"Total clusters found (excluding noise): {len(hdbscan_clusters)}")
for label, tags in hdbscan_clusters.items():
    print(f"\nCluster {label} ({len(tags)} tags):")
    print(tags[:10])  # Show first 10 tags per cluster

# Step 9: Visualization with t-SNE
print("Visualizing clusters...")
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
tsne_result = tsne.fit_transform(embeddings_scaled)

plt.figure(figsize=(12, 8))
scatter = plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=[label if label != -1 else 99 for label in cluster_labels], cmap='tab20', alpha=0.7)
plt.title('HDBSCAN Clustering of Health Tags (FastText Embeddings)')
plt.xlabel('t-SNE Dim 1')
plt.ylabel('t-SNE Dim 2')
plt.colorbar(scatter, label='Cluster Label (-1 = Noise)')
plt.show()
# Out:
# Running HDBSCAN clustering...
# C:\Users\nastya\thesis\tum-thesis\gensim_env\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\nastya\thesis\tum-thesis\gensim_env\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Total clusters found (excluding noise): 16
#
# Cluster 14 (829 tags):
# ['azilect', 'pancrelipase', 'zepatier', 'rivotril', 'haldol', 'calquence', 'librium', 'audavate', 'budenofalk', 'ofev']
#
# Cluster 0 (7 tags):
# ['vaniqa cream', 'epaderm cream', 'efudix cream', 'e45 cream', 'dermol cream', 'calmurid cream', 'fucidin cream']
#
# Cluster 8 (14 tags):
# ['wolffparkinsonwhite syndrome wpw', 'sjogrens syndrome', 'guillainbarre syndrome', 'cushings syndrome', 'cogans syndrome', 'noonan syndrome', 'beckwithwiedemann syndrome', 'nephrotic syndrome', 'brugada syndrome', 'gilberts syndrome']
#
# Cluster 15 (23 tags):
# ['prochlorperazine', 'triamterene  hydrochlorothiazide', 'hydroxyzine', 'lisinopril  hydrochlorothiazide', 'trihexyphenidyl', 'amitriptyline  perphenazine', 'fludarabine cyclophosphamide and rituximab fcr', 'valsartan  hydrochlorothiazide', 'procarbazine', 'telmisartan  amlodipine']
#
# Cluster 13 (38 tags):
# ['functional neurological disorder fnd', 'cerebral autosomal dominant arteriopathy with subcortical infarcts and leukoencephalopathy cadasil', 'hashimotos disease', 'separation anxiety disorder', 'huntingtons disease', 'cerebral autosomal recessive arteriopathy with subcortical infarcts and leukoencephalopathy carasil', 'chronic obstructive pulmonary disease copd', 'addisons disease', 'granulomatosis with polyangiitis', 'depression disorder']
#
# Cluster 6 (22 tags):
# ['hylocare eye drops', 'refresh eye drops', 'alphagan eye drops', 'ciloxan eye drops', 'celluvisc eye drops', 'optive eye drops', 'ganfort eye drops', 'cosopt eye drops', 'azarga eye drops', 'azopt eye drops']
#
# Cluster 10 (8 tags):
# ['linagliptin  metformin', 'metformin', 'dapagliflozin  metformin', 'vildagliptin  metformin', 'metformin  glipizide', 'empagliflozin  metformin', 'sitagliptin  metformin', 'alogliptin  metformin']
#
# Cluster 2 (8 tags):
# ['lipoic acid', 'tranexamic acid', 'hyaluronic acid', 'salicylic acid', 'acetic acid', 'ursodeoxycholic acid', 'valproic acid', 'zoledronic acid']
#
# Cluster 5 (14 tags):
# ['magnesium deficiency', 'sodium', 'calcium citrate', 'solgar magnesium citrate', 'potassium gluconate', 'sodium cromoglicate', 'sodium aurothiomalate', 'magnesium citrate', 'potassium citrate', 'calcium  magnesium']
#
# Cluster 1 (9 tags):
# ['venlalic xl', 'requip xl', 'pamsvax xl', 'carmil xl', 'xaggitin xl', 'vensir xl', 'monomil xl', 'concerta xl', 'trangina xl']
#
# Cluster 9 (9 tags):
# ['gallbladder cancer', 'breast cancer metastatic', 'vulval cancer', 'peritoneal cancer', 'pancreatic cancer', 'testicular cancer', 'oesophageal cancer', 'prostate cancer', 'stomach cancer']
#
# Cluster 11 (15 tags):
# ['ultrasound therapy', 'combination therapy', 'parathyroid hormone pth', 'gonadotrophin releasing hormone gnrh', 'behavioural therapy', 'photodynamic therapy', 'computerassisted radiation therapy', 'luteinizing hormone releasing hormone lhrh agonist', 'hormone replacement therapy hrt', 'hyperthermia therapy']
#
# Cluster 4 (7 tags):
# ['insulin glulisine', 'insulin glargine', 'insulin regular', 'regular insulin', 'insulin resistance', 'insulin aspart', 'insulin degludec']
#
# Cluster 3 (8 tags):
# ['alendronic acid  colecalciferol', 'azelaic acid', 'mefenamic acid', 'alendronic acid', 'fusidic acid', 'obeticholic acid', 'aminosalicylic acid', 'ibandronic acid']
#
# Cluster 12 (5 tags):
# ['natural thyroid', 'thyroid conditions', 'underactive thyroid hypothyroidism', 'overactive thyroid hyperthyroidism', 'natural desiccated thyroid ndt']
#
# Cluster 7 (6 tags):
# ['reconstructive surgery', 'urologic surgery', 'gynecological surgery', 'mohs surgery', 'debulking surgery', 'surgery']
# Visualizing clusters...

# %% [markdown]
# ### Sentence Transformer + K-Means

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
# import umap
import hdbscan
import numpy as np
import json

# Load tags
with open('all_tags.json', 'r', encoding='utf-8') as file:
    tags = json.load(file)

# Initialize transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Generate embeddings
embeddings = model.encode(tags)

# # Optional: UMAP reduction
# umap_embeddings = umap.UMAP(n_neighbors=15, n_components=10, metric='cosine').fit_transform(embeddings)

# Apply HDBSCAN
clusterer = hdbscan.HDBSCAN(min_cluster_size=5, metric='euclidean')
labels = clusterer.fit_predict(embeddings)

# Print results
print(set(labels), "Clusters found")

# Optional: Save clusters
clusters = {}
for tag, label in zip(tags, labels):
    clusters.setdefault(str(label), []).append(tag)

with open('llm_clusters.json', 'w', encoding='utf-8') as file:
    json.dump(clusters, file, indent=4)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# C:\Users\nastya\thesis\tum-thesis\gensim_env\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\nastya\thesis\tum-thesis\gensim_env\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# {0, 1, 2, -1} Clusters found
