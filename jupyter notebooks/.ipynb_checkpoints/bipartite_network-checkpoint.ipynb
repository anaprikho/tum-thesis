# %% [markdown]
# # Extend profile data by tag_to_cluster mapping

# %% [markdown]
# ## Ceate a dict: {tag: cluster}

# %%
import json
import os

base_dir = os.path.abspath("..")
input_path = os.path.join(base_dir, "data", "tag_clustering", "tags_clustered.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "tag_to_cluster_mapping.json")

# Load file with clusters
with open(input_path, "r", encoding="utf-8") as f:
    clustered = json.load(f)

# Invert to {tag: cluster}
tag_to_cluster = {}
for cluster, tags in clustered.items():
    for tag in tags:
        tag_to_cluster[tag] = cluster

# Save file with mapping
with open(output_path, "w", encoding="utf-8") as out:
    json.dump(tag_to_cluster, out, indent=2)

print(f"Saved tag-to-cluster mapping to: {output_path}")
print(f"Total tags mapped: {len(tag_to_cluster)}")
# Out:
# Saved tag-to-cluster mapping to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\tag_to_cluster_mapping.json
# Total tags mapped: 2965

# %% [markdown]
# ## Extend profiles file by adding "tag_clusters":
#         "tags": [
#             "Lung disease",
#             "Oxygen Therapy",
#             "Respiratory failure"
#         ],
#         "tags_clusters" [
# 		        "Respiratory desease",
# 		        "Respiratory desease",
# 		        "Respiratory desease"
#         ],

# %% [markdown]
# ### general_profiles_data.json

# %%
import json
import os

base_dir = os.path.abspath("..")
general_profiles_path = os.path.join(base_dir, "data", "data_cleaned", "general_profiles_data.json")
tag_map_path = os.path.join(base_dir, "data", "bipartite_network", "tag_to_cluster_mapping.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "general_profiles_data_with_tag_clusters.json")

# Load files
with open(general_profiles_path, "r", encoding="utf-8") as f:
    general_profiles = json.load(f)

with open(tag_map_path, "r", encoding="utf-8") as f:
    tag_to_cluster = json.load(f)

# Extend each profile with tag_clusters
for username, profile in general_profiles.items():
    tags = profile.get("tags", [])
    tag_clusters = [tag_to_cluster.get(tag, "N/A") for tag in tags]
    profile["tag_clusters"] = tag_clusters

# Save the updated profiles
with open(output_path, "w", encoding="utf-8") as out:
    json.dump(general_profiles, out, indent=2)

print(f"Extended profiles saved to: {output_path}")
# Out:
# Extended profiles saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\general_profiles_data_with_tag_clusters.json

# %% [markdown]
# ### profile_by_comm_data.json

# %%
import json
import os

base_dir = os.path.abspath("..")
profiles_path = os.path.join(base_dir, "data", "data_cleaned", "profiles_by_comm_data.json")
tag_map_path = os.path.join(base_dir, "data", "bipartite_network", "tag_to_cluster_mapping.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "community-specific_patterns", "profiles_by_comm_data_with_tag_clusters.json")

# Load files
with open(profiles_path, "r", encoding="utf-8") as f:
    profiles_data = json.load(f)

with open(tag_map_path, "r", encoding="utf-8") as f:
    tag_to_cluster = json.load(f)

# Extend each profile with tag_clusters
for comm, users in profiles_data.items():
    for username, profile in users.items():
        tags = profile.get("tags", [])
        tag_clusters = [tag_to_cluster.get(tag, "N/A") for tag in tags]
        profile["tag_clusters"] = tag_clusters

# Save the updated profiles
with open(output_path, "w", encoding="utf-8") as out:
    json.dump(profiles_data, out, indent=2)

print(f"Extended profiles saved to: {output_path}")
# Out:
# Extended profiles saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\profiles_by_comm_data_with_tag_clusters.json

# %% [markdown]
# # Create Bipartite Network

# %% [markdown]
# ## 1. General Pattern

# %% [markdown]
# ### Create an edge list (source-target node): 3 cols
# coachtrip | repiratory desease | 3 (weight for req of co-occurence)

# %%
import json
import os
import networkx as nx
from collections import defaultdict, Counter
import pandas as pd

base_dir = os.path.abspath("..")
file_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "general_profiles_data_with_tag_clusters.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "cluster_co-occurrence_edges.json")

# Load file with profiles & tag-to-cluster mapping
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# 1. Create an edge list (user, cluster, weight)
# user - source node
# cluster - target node
# weight - for frequency of co-occurrence
edge_counts = defaultdict(int)
users_with_tags = set()

for user, info in data.items():
    clusters = info.get("tag_clusters", [])
    for cluster in clusters:
        if cluster != "N/A":
            edge_counts[(user, cluster)] += 1
            users_with_tags.add(user)

# 2. Create a bipartite graph (2 types of nodes: Users & Clusters)
# Input: nodes (source & target) & edge list
B = nx.Graph()

# Add nodes (Users & Clusters)
users = set()
clusters = set()

for (user, cluster), weight in edge_counts.items():
    users.add(user)
    clusters.add(cluster)
    B.add_node(user, bipartite=0)  # users
    B.add_node(cluster, bipartite=1)  # clusters
    B.add_edge(user, cluster, weight=weight)

# Visualize an edge list
edge_list = [(u, c, w) for (u, c), w in edge_counts.items()]
df = pd.DataFrame(edge_list, columns=["user", "cluster", "weight"])
print(df.head(10))

# 3. Project to cluster-cluster co-occurrence network
projected = nx.bipartite.weighted_projected_graph(B, clusters)

# 4. Save the projected network edge list (cluster co-occurrence)
cooccurrence_edges = [
    {"source": u, "target": v, "weight": d["weight"]}
    for u, v, d in projected.edges(data=True)
]

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(cooccurrence_edges, f, indent=2)

print(f"\nProjected cluster co-occurrence edges saved to: {output_path}")

print("\nSummary:")
print(f"Total users in file: {len(data)}")
print(f"Users with at least one cluster: {len(users_with_tags)}")
print(f"Total user-cluster edges: {len(edge_counts)}")
print(f"Unique clusters: {len(clusters)}")
print(f"Edges in projected cluster-cluster graph: {projected.number_of_edges()}")
# Out:
#          user                              cluster  weight
# 0   Coachtrip  Respiratory Conditions & Treatments       3
# 1  Wegeners88                  Autoimmune Diseases       1
# 2  Wegeners88      Metabolic & Endocrine Disorders       2
# 3  Wegeners88        Preventive Health & Screening       1
# 4  Wegeners88              Cardiovascular Diseases       2
# 5  Wegeners88         Hematology & Blood Disorders       1
# 6  Wegeners88        Lifestyle, Diet & Supplements       3
# 7  Tumorboy20               Neurological Disorders       2
# 8  Bodypump51              Cardiovascular Diseases       8
# 9  Bodypump51        Lifestyle, Diet & Supplements       4
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\cluster_co-occurrence_edges.json
#
# Summary:
# Total users in file: 8554
# Users with at least one cluster: 8554
# Total user-cluster edges: 22138
# Unique clusters: 23
# Edges in projected cluster-cluster graph: 253

# %% [markdown]
# ### Demographic Group: Gender

# %% [markdown]
# (male, female) - 2 networks

# %%
import json
import os
import networkx as nx
from collections import defaultdict, Counter
import pandas as pd

base_dir = os.path.abspath("..")
file_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "general_profiles_data_with_tag_clusters.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics", "gender")

# Load file with profiles & tag-to-cluster mapping
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# 1. Create an edge list (user, cluster, weight)
# user - source node
# cluster - target node
# weight - for frequency of co-occurrence
# and split by gender
edge_counts = {
    "male": defaultdict(int),
    "female": defaultdict(int)
}
users_with_tags = {
    "male": set(),
    "female": set()
}

for user, info in data.items():
    clusters = info.get("tag_clusters", [])
    gender = info.get("demographics", {}).get("gender", "").lower()

    if gender in ["male"]: group = "male"
    elif gender in ["female"]: group ="female"
    else: continue  # skip if gender is "N/A" or "Others"
    
    for cluster in clusters:
        if cluster != "N/A":
            edge_counts[group][(user, cluster)] += 1
            users_with_tags[group].add(user)

def build_and_project_graph(group):
    # 2. Create a bipartite graph (2 types of nodes: Users & Clusters)
    # Input: nodes (source & target) & edge list
    B = nx.Graph()
    
    # Add nodes (Users & Clusters)
    users = set()
    clusters = set()
    
    for (user, cluster), weight in edge_counts[group].items():
        users.add(user)
        clusters.add(cluster)
        B.add_node(user, bipartite=0)  # users
        B.add_node(cluster, bipartite=1)  # clusters
        B.add_edge(user, cluster, weight=weight)
    
    # Visualize an edge list
    edge_list = [(u, c, w) for (u, c), w in edge_counts[group].items()]
    df = pd.DataFrame(edge_list, columns=["user", "cluster", "weight"])
    print(df.head(10))
    
    # 3. Project to cluster-cluster co-occurrence network
    projected = nx.bipartite.weighted_projected_graph(B, clusters)
    
    # 4. Save the projected network edge list (cluster co-occurrence)
    cooccurrence_edges = [
        {"source": u, "target": v, "weight": d["weight"]}
        for u, v, d in projected.edges(data=True)
    ]

    file_name = os.path.join(output_path, f"cluster_co-occurrence_{group}.json")
    
    with open(file_name, "w", encoding="utf-8") as f:
        json.dump(cooccurrence_edges, f, indent=2)
    
    print(f"\nProjected cluster co-occurrence edges saved to: {file_name}")
    
    print(f"\nSummary for {group}- users:")
    # print(f"Total users in file: {len(data)}")
    print(f"Users with at least one cluster: {len(users_with_tags[group])}")
    print(f"Total user-cluster edges: {len(edge_counts[group])}")
    print(f"Unique clusters: {len(clusters)}")
    print(f"Edges in projected cluster-cluster graph: {projected.number_of_edges()}")

    return df

# Run for each gender group
df_male = build_and_project_graph("male")
df_female = build_and_project_graph("female")
# Out:
#           user                              cluster  weight
# 0   Tumorboy20               Neurological Disorders       2
# 1       Anasjk  Mental Health & Emotional Wellbeing       1
# 2  707twitcher               Neurological Disorders       1
# 3  707twitcher    Pain & Musculoskeletal Conditions       1
# 4  707twitcher  Mental Health & Emotional Wellbeing       2
# 5        85745                    Cancer & Oncology       1
# 6        85745        Lifestyle, Diet & Supplements       1
# 7       Sunset                  Autoimmune Diseases       1
# 8       Sunset        Lifestyle, Diet & Supplements       2
# 9       Sunset          Substance Abuse & Addiction       1
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\gender\cluster_co-occurrence_male.json
#
# Summary for male- users:
# Users with at least one cluster: 2005
# Total user-cluster edges: 5330
# Unique clusters: 23
# Edges in projected cluster-cluster graph: 232
#              user                          cluster  weight
# 0      Wegeners88              Autoimmune Diseases       1
# 1      Wegeners88  Metabolic & Endocrine Disorders       2
# 2      Wegeners88    Preventive Health & Screening       1
# 3      Wegeners88          Cardiovascular Diseases       2
# 4      Wegeners88     Hematology & Blood Disorders       1
# 5      Wegeners88    Lifestyle, Diet & Supplements       3
# 6      Bodypump51          Cardiovascular Diseases       8
# 7      Bodypump51    Lifestyle, Diet & Supplements       4
# 8  mubashrashafiq    Lifestyle, Diet & Supplements       1
# 9    Lizzyanne567    Lifestyle, Diet & Supplements       3
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\gender\cluster_co-occurrence_female.json
#
# Summary for female- users:
# Users with at least one cluster: 4440
# Total user-cluster edges: 12754
# Unique clusters: 23
# Edges in projected cluster-cluster graph: 252

# %% [markdown]
# ### Demographic Group: Country

# %% [markdown]
# matching technique “**propencity score matching**” for e.g. USA (2000) vs UK (4000) https://pypi.org/project/psmpy/
#
# propencity score matching is technique used in causation analysis

# %% [raw]
#                  Country  Count  Percentage
# 0         United Kingdom   3584   41.898527
# 1                    N/A   2273   26.572364
# 2          United States   1886   22.048165
# 3                 Canada    176    2.057517
# 4              Australia    113    1.321019
# 5                  India     73    0.853402
# 6                Ireland     68    0.794950
# 7            New Zealand     39    0.455927
# 8                 France     31    0.362404
# 9           South Africa     22    0.257190
# 10                 Spain     20    0.233809
# 11               Germany     19    0.222118
# 12               Belgium     13    0.151976
# 13                 Italy     12    0.140285
# 14           Netherlands     11    0.128595
# 15               Nigeria     10    0.116904
#
# If filter countries with percentage > 5%, Ireland is the last.

# %% [markdown]
# #### **1. Australia | India | Canada | Ireland (w/o matching)**

# %%
import json
import os
import networkx as nx
from collections import defaultdict, Counter
import pandas as pd

base_dir = os.path.abspath("..")
file_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "general_profiles_data_with_tag_clusters.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics", "country", "Australia - India - Canada - Ireland")

# Load file with profiles & tag-to-cluster mapping
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Define countries of a subgroup
target_countries = ["Australia", "India", "Canada", "Ireland"]

# 1. Create an edge list (user, cluster, weight)
# user - source node
# cluster - target node
# weight - for frequency of co-occurrence
# and split by country
edge_counts = {country: defaultdict(int) for country in target_countries}
users_with_tags = {country: set() for country in target_countries}

for user, info in data.items():
    clusters = info.get("tag_clusters", [])
    country = info.get("demographics", {}).get("country")

    if country not in target_countries:
        continue
    
    for cluster in clusters:
        if cluster != "N/A":
            edge_counts[country][(user, cluster)] += 1
            users_with_tags[country].add(user)

def build_and_project_graph(country):
    # 2. Create a bipartite graph (2 types of nodes: Users & Clusters)
    # Input: nodes (source & target) & edge list
    B = nx.Graph()
    
    # Add nodes (Users & Clusters)
    users = set()
    clusters = set()
    
    for (user, cluster), weight in edge_counts[country].items():
        users.add(user)
        clusters.add(cluster)
        B.add_node(user, bipartite=0)  # users
        B.add_node(cluster, bipartite=1)  # clusters
        B.add_edge(user, cluster, weight=weight)
    
    # Show edge list
    edge_list = [(u, c, w) for (u, c), w in edge_counts[country].items()]
    df = pd.DataFrame(edge_list, columns=["user", "cluster", "weight"])
    print(df.head(5))
    
    # 3. Project to cluster-cluster co-occurrence network
    projected = nx.bipartite.weighted_projected_graph(B, clusters)
    
    # 4. Save the projected network edge list (cluster co-occurrence)
    cooccurrence_edges = [
        {"source": u, "target": v, "weight": d["weight"]}
        for u, v, d in projected.edges(data=True)
    ]

    file_name = os.path.join(output_path, f"cluster_co-occurrence_{country}.json")
    
    with open(file_name, "w", encoding="utf-8") as f:
        json.dump(cooccurrence_edges, f, indent=2)
    
    print(f"\nProjected cluster co-occurrence edges saved to: {file_name}")
    
    print(f"\nSummary for {country} - users:")
    # print(f"Total users in file: {len(data)}")
    print(f"Users with at least one cluster: {len(users_with_tags[country])}")
    print(f"Total user-cluster edges: {len(edge_counts[country])}")
    print(f"Unique clusters: {len(clusters)}")
    print(f"Edges in projected cluster-cluster graph: {projected.number_of_edges()}")

    return df

# Run for each country
df_au = build_and_project_graph("Australia")
df_in = build_and_project_graph("India")
df_ca = build_and_project_graph("Canada")
df_ir = build_and_project_graph("Ireland")
# Out:
#           user                            cluster  weight
# 0  Retiredlady            Cardiovascular Diseases       2
# 1  Retiredlady             Neurological Disorders       1
# 2  Retiredlady  Pain & Musculoskeletal Conditions       1
# 3    restlegs1             Neurological Disorders       1
# 4    restlegs1  Pain & Musculoskeletal Conditions       2
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\country\Australia - India - Canada - Ireland\cluster_co-occurrence_Australia.json
#
# Summary for Australia - users:
# Users with at least one cluster: 113
# Total user-cluster edges: 310
# Unique clusters: 20
# Edges in projected cluster-cluster graph: 122
#            user                                            cluster  weight
# 0   Gryffin1319                Mental Health & Emotional Wellbeing       4
# 1   Gryffin1319  Reproductive & Sexual Health (Women's Health &...       1
# 2  Mohammad-341                Mental Health & Emotional Wellbeing       4
# 3  Mohammad-341  Reproductive & Sexual Health (Women's Health &...       1
# 4  Mohammad-341                      Lifestyle, Diet & Supplements       3
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\country\Australia - India - Canada - Ireland\cluster_co-occurrence_India.json
#
# Summary for India - users:
# Users with at least one cluster: 73
# Total user-cluster edges: 161
# Unique clusters: 19
# Edges in projected cluster-cluster graph: 70
#                 user                                            cluster  \
# 0             Quilt2     Digestive Health (Gastrointestinal Conditions)
# 1  Sleeplessinbitola                             Neurological Disorders
# 2        Aishandrumi                Mental Health & Emotional Wellbeing
# 3        Aishandrumi                      Lifestyle, Diet & Supplements
# 4        Aishandrumi  Reproductive & Sexual Health (Women's Health &...
#
#    weight
# 0       1
# 1       1
# 2       4
# 3       1
# 4       1
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\country\Australia - India - Canada - Ireland\cluster_co-occurrence_Canada.json
#
# Summary for Canada - users:
# Users with at least one cluster: 176
# Total user-cluster edges: 524
# Unique clusters: 22
# Edges in projected cluster-cluster graph: 148
#          user                             cluster  weight
# 0  Tobias1234              Neurological Disorders       1
# 1       mitsy             Cardiovascular Diseases       1
# 2  JezzaJezza             Cardiovascular Diseases       6
# 3  JezzaJezza       Lifestyle, Diet & Supplements       7
# 4  JezzaJezza  Medications & Treatment Monitoring       1
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\country\Australia - India - Canada - Ireland\cluster_co-occurrence_Ireland.json
#
# Summary for Ireland - users:
# Users with at least one cluster: 68
# Total user-cluster edges: 177
# Unique clusters: 19
# Edges in projected cluster-cluster graph: 76

# %% [markdown]
# #### **2. UK | US (w/ matching)**
#    prepare data for propensity score matching (PSM) USA (2000) vs. UK (4000)

# %% [markdown]
# ##### Propensity Matching Score (PSM)

# %%
import os
import json
import pandas as pd

base_dir = os.path.abspath("..")
file_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "general_profiles_data_with_tag_clusters.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics", "country", "UK - US", "pms_matched_user_ids.json")

# Load file with profiles & tag-to-cluster mapping
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Extract relevant user info (age, gender) into rows (one row for each user)
rows = []
for user, info in data.items():
    demographics = info.get("demographics", {})
    
    country = demographics.get("country", "N/A")
    age = demographics.get("age", "N/A")
    gender = demographics.get("gender", "N/A")

    # Save row for this user
    rows.append({
        "user": user,
        "country": country,
        "age": age,
        "gender": gender
    })

df = pd.DataFrame(rows)

# %%
countries = ["United Kingdom", "United States"]

# Filter based on countries of interest
df_filtered = df[df["country"].isin(countries)].copy()

# Remove rows with no age and gender
df_filtered = df_filtered[~df_filtered["age"].isin(["N/A"])]
df_filtered = df_filtered[~df_filtered["gender"].isin(["N/A", "Others"])]

# Convert age to numeric type
df_filtered["age"] = pd.to_numeric(df_filtered["age"], errors="coerce")

# Remove rows where age could not be converted
df_filtered = df_filtered.dropna(subset=["age"])

print(f"UK: {df_filtered[df_filtered['country'] == 'United Kingdom'].shape[0]}")
print(f"USA: {df_filtered[df_filtered['country'] == 'United States'].shape[0]}")

df_filtered.head(5)
print("\n", df_filtered["gender"].value_counts())
# print("\n", df_filtered["age"].value_counts())
# Out:
# UK: 1821
# USA: 1125
#
#  gender
# Female    1940
# Male      1006
# Name: count, dtype: int64

# %%
from psmpy import PsmPy
from psmpy.functions import cohenD

# Encode gender
df_filtered["gender"] = df_filtered["gender"].str.lower().str.strip()
df_filtered["gender_encoded"] = df_filtered["gender"].map({"male": 0, "female": 1})

# Create df for PSM
psm_df = df_filtered[["user", "country", "age", "gender_encoded"]].copy()

# Define treatment variable (USA = 1, UK = 0)
psm_df["treatment"] = psm_df["country"].apply(lambda x: 1 if x == "United States" else 0)

# Initialize PSM model
psm = PsmPy(psm_df,
            treatment='treatment',
            indx='user',
            exclude=['country'])  # exclude non-covariates

# Estimate propensity scores via logistic regression
psm.logistic_ps(balance=True)

# Nearest neighbor matching 1:1
psm.knn_matched(matcher='propensity_logit', replacement=False)

# Plot balance check (optional)
psm.plot_match(Title='Propensity Score Matching: UK vs. USA (age & gender only)')

# Merge matched users with original df to get country info
# matched_df = psm.df_matched.merge(df_filtered[["user", "country"]], left_index=True, right_on="user")
matched_df = psm.df_matched.reset_index().merge(
    df_filtered[["user", "country"]], on="user"
)

# Get matched samples
# matched_df = psm.df_matched
uk_matched = matched_df[matched_df["country"] == "United Kingdom"]
us_matched = matched_df[matched_df["country"] == "United States"]

print(f"Matched UK users: {len(uk_matched)}")
print(f"Matched US users: {len(us_matched)}")

# Extract IDs of matches users
uk_user_ids = uk_matched["user"].tolist()
us_user_ids = us_matched["user"].tolist()

matched_ids = {
    "UK": uk_user_ids,
    "US": us_user_ids
}

# Save to JSON file
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(matched_ids, f, indent=2)
# Out:
# C:\Users\nastya\thesis\tum-thesis\gensim_env\Lib\site-packages\psmpy\psmpy.py:363: UserWarning: Some values do not have a match. These are dropped for purposes of establishing a matched dataframe, and subsequent calculations and plots (effect size). If you do not wish this to be the case please set drop_unmatched=False
#   warnings.warn('Some values do not have a match. These are dropped for purposes of establishing a matched dataframe, and subsequent calculations and plots (effect size). If you do not wish this to be the case please set drop_unmatched=False')
# Matched UK users: 1124
# Matched US users: 1125

# %% [markdown]
# ##### Bipartite Network & Projection

# %%
import json
import os
import networkx as nx
from collections import defaultdict, Counter
import pandas as pd

base_dir = os.path.abspath("..")
file_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "general_profiles_data_with_tag_clusters.json")
matched_user_ids = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics","country", "UK - US", "pms_matched_user_ids.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics", "country", "UK - US")

# Load file with profiles & tag-to-cluster mapping
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Load file with matched user ids (w. PMS)
with open(matched_user_ids, "r", encoding="utf-8") as f:
    matched_users_data = json.load(f)

# Combine PMS-matched users for UK and USA
pms_matched_users = set(matched_users_data.get("UK", []) + matched_users_data.get("US", []))

# Define countries of a subgroup
target_countries = ["United Kingdom", "United States"]

# 1. Create an edge list (user, cluster, weight)
# user - source node
# cluster - target node
# weight - for frequency of co-occurrence
# and split by country
edge_counts = {country: defaultdict(int) for country in target_countries}
users_with_tags = {country: set() for country in target_countries}

for user, info in data.items():
    if user not in pms_matched_users:
        continue
        
    clusters = info.get("tag_clusters", [])
        
    country = info.get("demographics", {}).get("country")

    if country not in target_countries:
        continue
    
    for cluster in clusters:
        if cluster != "N/A":
            edge_counts[country][(user, cluster)] += 1
            users_with_tags[country].add(user)

def build_and_project_graph(country):
    # 2. Create a bipartite graph (2 types of nodes: Users & Clusters)
    # Input: nodes (source & target) & edge list
    B = nx.Graph()
    
    # Add nodes (Users & Clusters)
    users = set()
    clusters = set()
    
    for (user, cluster), weight in edge_counts[country].items():
        users.add(user)
        clusters.add(cluster)
        B.add_node(user, bipartite=0)  # users
        B.add_node(cluster, bipartite=1)  # clusters
        B.add_edge(user, cluster, weight=weight)
    
    # Show edge list
    edge_list = [(u, c, w) for (u, c), w in edge_counts[country].items()]
    df = pd.DataFrame(edge_list, columns=["user", "cluster", "weight"])
    print(df.head(5))
    
    # 3. Project to cluster-cluster co-occurrence network
    projected = nx.bipartite.weighted_projected_graph(B, clusters)
    
    # 4. Save the projected network edge list (cluster co-occurrence)
    cooccurrence_edges = [
        {"source": u, "target": v, "weight": d["weight"]}
        for u, v, d in projected.edges(data=True)
    ]

    file_name = os.path.join(output_path, f"cluster_co-occurrence_{country}.json")
    
    with open(file_name, "w", encoding="utf-8") as f:
        json.dump(cooccurrence_edges, f, indent=2)
    
    print(f"\nProjected cluster co-occurrence edges saved to: {file_name}")
    
    print(f"\nSummary for {country} - users:")
    # print(f"Total users in file: {len(data)}")
    print(f"Users with at least one cluster: {len(users_with_tags[country])}")
    print(f"Total user-cluster edges: {len(edge_counts[country])}")
    print(f"Unique clusters: {len(clusters)}")
    print(f"Edges in projected cluster-cluster graph: {projected.number_of_edges()}")

    return df

# Run for each country
df_uk = build_and_project_graph("United Kingdom")
df_us = build_and_project_graph("United States")
# Out:
#         user                                         cluster  weight
# 0  Rubytunes                         Cardiovascular Diseases       2
# 1  Rubytunes  Digestive Health (Gastrointestinal Conditions)       1
# 2  Rubytunes                      Dermatology & Skin-Related       1
# 3  Pastamama                             Autoimmune Diseases       2
# 4  Pastamama                   Lifestyle, Diet & Supplements       4
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\country\UK - US\cluster_co-occurrence_United Kingdom.json
#
# Summary for United Kingdom - users:
# Users with at least one cluster: 1124
# Total user-cluster edges: 3279
# Unique clusters: 23
# Edges in projected cluster-cluster graph: 235
#           user                              cluster  weight
# 0   Tumorboy20               Neurological Disorders       2
# 1  707twitcher               Neurological Disorders       1
# 2  707twitcher    Pain & Musculoskeletal Conditions       1
# 3  707twitcher  Mental Health & Emotional Wellbeing       2
# 4        85745                    Cancer & Oncology       1
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\country\UK - US\cluster_co-occurrence_United States.json
#
# Summary for United States - users:
# Users with at least one cluster: 1125
# Total user-cluster edges: 3195
# Unique clusters: 23
# Edges in projected cluster-cluster graph: 245

# %% [markdown]
# #### **3. US | Canada (w/ matching)**

# %% [markdown]
# ##### Propensity Matching Score (PMS)

# %%
import os
import json
import pandas as pd

base_dir = os.path.abspath("..")
file_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "general_profiles_data_with_tag_clusters.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics", "country", "US - Canada", "pms_matched_user_ids.json")

# Load file with profiles & tag-to-cluster mapping
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Extract relevant user info (age, gender) into rows (one row for each user)
rows = []
for user, info in data.items():
    demographics = info.get("demographics", {})
    
    country = demographics.get("country", "N/A")
    age = demographics.get("age", "N/A")
    gender = demographics.get("gender", "N/A")

    # Save row for this user
    rows.append({
        "user": user,
        "country": country,
        "age": age,
        "gender": gender
    })

df = pd.DataFrame(rows)

countries = ["United States", "Canada"]

# Filter based on countries of interest
df_filtered = df[df["country"].isin(countries)].copy()

# Remove rows with no age and gender
df_filtered = df_filtered[~df_filtered["age"].isin(["N/A"])]
df_filtered = df_filtered[~df_filtered["gender"].isin(["N/A", "Others"])]

# Convert age to numeric type
df_filtered["age"] = pd.to_numeric(df_filtered["age"], errors="coerce")

# Remove rows where age could not be converted
df_filtered = df_filtered.dropna(subset=["age"])

print(f"USA: {df_filtered[df_filtered['country'] == 'United States'].shape[0]}")
print(f"UK: {df_filtered[df_filtered['country'] == 'Canada'].shape[0]}")

df_filtered.head(5)
print("\n", df_filtered["gender"].value_counts())
# print("\n", df_filtered["age"].value_counts())
# Out:
# USA: 1125
# UK: 104
#
#  gender
# Female    677
# Male      552
# Name: count, dtype: int64

# %%
from psmpy import PsmPy
from psmpy.functions import cohenD

# Encode gender
df_filtered["gender"] = df_filtered["gender"].str.lower().str.strip()
df_filtered["gender_encoded"] = df_filtered["gender"].map({"male": 0, "female": 1})

# Create df for PSM
psm_df = df_filtered[["user", "country", "age", "gender_encoded"]].copy()

# Define treatment variable (USA = 1, Canada = 0)
psm_df["treatment"] = psm_df["country"].apply(lambda x: 1 if x == "United States" else 0)

# Initialize PSM model
psm = PsmPy(psm_df,
            treatment='treatment',
            indx='user',
            exclude=['country'])  # exclude non-covariates

# Estimate propensity scores via logistic regression
psm.logistic_ps(balance=True)

# Nearest neighbor matching 1:1
psm.knn_matched(matcher='propensity_logit', replacement=False)

# Plot balance check (optional)
psm.plot_match(Title='Propensity Score Matching: Canada vs. USA (age & gender only)')

# Merge matched users with original df to get country info
# matched_df = psm.df_matched.merge(df_filtered[["user", "country"]], left_index=True, right_on="user")
matched_df = psm.df_matched.reset_index().merge(
    df_filtered[["user", "country"]], on="user"
)

# Get matched samples
# matched_df = psm.df_matched
us_matched = matched_df[matched_df["country"] == "United States"]
canada_matched = matched_df[matched_df["country"] == "Canada"]

print(f"Matched US users: {len(us_matched)}")
print(f"Matched Canada users: {len(canada_matched)}")

# Extract IDs of matches users
us_user_ids = us_matched["user"].tolist()
canada_user_ids = canada_matched["user"].tolist()

matched_ids = {
    "US": us_user_ids,
    "Canada": canada_user_ids,
}

# Save to JSON file
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(matched_ids, f, indent=2)
# Out:
# Matched US users: 104
# Matched Canada users: 104

# %% [markdown]
# ##### Bipartite Network & Projection

# %%
import json
import os
import networkx as nx
from collections import defaultdict, Counter
import pandas as pd

base_dir = os.path.abspath("..")
file_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "general_profiles_data_with_tag_clusters.json")
matched_user_ids = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics","country", "US - Canada", "pms_matched_user_ids.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics", "country", "US - Canada")

# Load file with profiles & tag-to-cluster mapping
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Load file with matched user ids (w. PMS)
with open(matched_user_ids, "r", encoding="utf-8") as f:
    matched_users_data = json.load(f)

# Combine PMS-matched users for US and Canada
pms_matched_users = set(matched_users_data.get("US", []) + matched_users_data.get("Canada", []))

# Define countries of a subgroup
target_countries = ["United States", "Canada"]

# 1. Create an edge list (user, cluster, weight)
# user - source node
# cluster - target node
# weight - for frequency of co-occurrence
# and split by country
edge_counts = {country: defaultdict(int) for country in target_countries}
users_with_tags = {country: set() for country in target_countries}

for user, info in data.items():
    if user not in pms_matched_users:
        continue
        
    clusters = info.get("tag_clusters", [])
        
    country = info.get("demographics", {}).get("country")

    if country not in target_countries:
        continue
    
    for cluster in clusters:
        if cluster != "N/A":
            edge_counts[country][(user, cluster)] += 1
            users_with_tags[country].add(user)

def build_and_project_graph(country):
    # 2. Create a bipartite graph (2 types of nodes: Users & Clusters)
    # Input: nodes (source & target) & edge list
    B = nx.Graph()
    
    # Add nodes (Users & Clusters)
    users = set()
    clusters = set()
    
    for (user, cluster), weight in edge_counts[country].items():
        users.add(user)
        clusters.add(cluster)
        B.add_node(user, bipartite=0)  # users
        B.add_node(cluster, bipartite=1)  # clusters
        B.add_edge(user, cluster, weight=weight)
    
    # Show edge list
    edge_list = [(u, c, w) for (u, c), w in edge_counts[country].items()]
    df = pd.DataFrame(edge_list, columns=["user", "cluster", "weight"])
    print(df.head(5))
    
    # 3. Project to cluster-cluster co-occurrence network
    projected = nx.bipartite.weighted_projected_graph(B, clusters)
    
    # 4. Save the projected network edge list (cluster co-occurrence)
    cooccurrence_edges = [
        {"source": u, "target": v, "weight": d["weight"]}
        for u, v, d in projected.edges(data=True)
    ]

    file_name = os.path.join(output_path, f"cluster_co-occurrence_{country}.json")
    
    with open(file_name, "w", encoding="utf-8") as f:
        json.dump(cooccurrence_edges, f, indent=2)
    
    print(f"\nProjected cluster co-occurrence edges saved to: {file_name}")
    
    print(f"\nSummary for {country} - users:")
    # print(f"Total users in file: {len(data)}")
    print(f"Users with at least one cluster: {len(users_with_tags[country])}")
    print(f"Total user-cluster edges: {len(edge_counts[country])}")
    print(f"Unique clusters: {len(clusters)}")
    print(f"Edges in projected cluster-cluster graph: {projected.number_of_edges()}")

    return df

# Run for each country
df_us = build_and_project_graph("United States")
df_canada = build_and_project_graph("Canada")
# Out:
#           user                              cluster  weight
# 0  707twitcher               Neurological Disorders       1
# 1  707twitcher    Pain & Musculoskeletal Conditions       1
# 2  707twitcher  Mental Health & Emotional Wellbeing       2
# 3      Rufus07  Mental Health & Emotional Wellbeing       3
# 4      Rufus07        Lifestyle, Diet & Supplements       3
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\country\US - Canada\cluster_co-occurrence_United States.json
#
# Summary for United States - users:
# Users with at least one cluster: 104
# Total user-cluster edges: 286
# Unique clusters: 21
# Edges in projected cluster-cluster graph: 121
#                 user                                            cluster  \
# 0  Sleeplessinbitola                             Neurological Disorders
# 1        Aishandrumi                Mental Health & Emotional Wellbeing
# 2        Aishandrumi                      Lifestyle, Diet & Supplements
# 3        Aishandrumi  Reproductive & Sexual Health (Women's Health &...
# 4         Bunchberry                                Autoimmune Diseases
#
#    weight
# 0       1
# 1       4
# 2       1
# 3       1
# 4       1
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\country\US - Canada\cluster_co-occurrence_Canada.json
#
# Summary for Canada - users:
# Users with at least one cluster: 104
# Total user-cluster edges: 315
# Unique clusters: 21
# Edges in projected cluster-cluster graph: 125

# %% [markdown]
# #### **4.UK | Ireland (w/ matching)**

# %% [markdown]
# ##### Propensity Matching Score (PMS)

# %%
import os
import json
import pandas as pd

base_dir = os.path.abspath("..")
file_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "general_profiles_data_with_tag_clusters.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics", "country", "UK - Ireland", "pms_matched_user_ids.json")

# Load file with profiles & tag-to-cluster mapping
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Extract relevant user info (age, gender) into rows (one row for each user)
rows = []
for user, info in data.items():
    demographics = info.get("demographics", {})
    
    country = demographics.get("country", "N/A")
    age = demographics.get("age", "N/A")
    gender = demographics.get("gender", "N/A")

    # Save row for this user
    rows.append({
        "user": user,
        "country": country,
        "age": age,
        "gender": gender
    })

df = pd.DataFrame(rows)

countries = ["United Kingdom", "Ireland"]

# Filter based on countries of interest
df_filtered = df[df["country"].isin(countries)].copy()

# Remove rows with no age and gender
df_filtered = df_filtered[~df_filtered["age"].isin(["N/A"])]
df_filtered = df_filtered[~df_filtered["gender"].isin(["N/A", "Others"])]

# Convert age to numeric type
df_filtered["age"] = pd.to_numeric(df_filtered["age"], errors="coerce")

# Remove rows where age could not be converted
df_filtered = df_filtered.dropna(subset=["age"])

print(f"UK: {df_filtered[df_filtered['country'] == 'United Kingdom'].shape[0]}")
print(f"Ireland: {df_filtered[df_filtered['country'] == 'Ireland'].shape[0]}")

df_filtered.head(5)
print("\n", df_filtered["gender"].value_counts())
# print("\n", df_filtered["age"].value_counts())
# Out:
# UK: 1821
# Ireland: 33
#
#  gender
# Female    1344
# Male       510
# Name: count, dtype: int64

# %%
from psmpy import PsmPy
from psmpy.functions import cohenD

# Encode gender
df_filtered["gender"] = df_filtered["gender"].str.lower().str.strip()
df_filtered["gender_encoded"] = df_filtered["gender"].map({"male": 0, "female": 1})

# Create df for PSM
psm_df = df_filtered[["user", "country", "age", "gender_encoded"]].copy()

# Define treatment variable (UK = 1, Ireland = 0)
psm_df["treatment"] = psm_df["country"].apply(lambda x: 1 if x == "United Kingdom" else 0)

# Initialize PSM model
psm = PsmPy(psm_df,
            treatment='treatment',
            indx='user',
            exclude=['country'])  # exclude non-covariates

# Estimate propensity scores via logistic regression
psm.logistic_ps(balance=True)

# Nearest neighbor matching 1:1
psm.knn_matched(matcher='propensity_logit', replacement=False)

# Plot balance check (optional)
psm.plot_match(Title='Propensity Score Matching: UK vs. Ireland (age & gender only)')

# Merge matched users with original df to get country info
# matched_df = psm.df_matched.merge(df_filtered[["user", "country"]], left_index=True, right_on="user")
matched_df = psm.df_matched.reset_index().merge(
    df_filtered[["user", "country"]], on="user"
)

# Get matched samples
# matched_df = psm.df_matched
uk_matched = matched_df[matched_df["country"] == "United Kingdom"]
ir_matched = matched_df[matched_df["country"] == "Ireland"]

print(f"Matched UK users: {len(uk_matched)}")
print(f"Matched Ireland users: {len(ir_matched)}")

# Extract IDs of matches users
uk_user_ids = uk_matched["user"].tolist()
ir_user_ids = ir_matched["user"].tolist()

matched_ids = {
    "UK": uk_user_ids,
    "Ireland": ir_user_ids
}

# Save to JSON file
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(matched_ids, f, indent=2)
# Out:
# Matched UK users: 33
# Matched Ireland users: 33

# %% [markdown]
# ##### Bipartite Network & Projection

# %%
import json
import os
import networkx as nx
from collections import defaultdict, Counter
import pandas as pd

base_dir = os.path.abspath("..")
file_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "general_profiles_data_with_tag_clusters.json")
matched_user_ids = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics","country", "UK - Ireland", "pms_matched_user_ids.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics", "country", "UK - Ireland")

# Load file with profiles & tag-to-cluster mapping
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Load file with matched user ids (w. PMS)
with open(matched_user_ids, "r", encoding="utf-8") as f:
    matched_users_data = json.load(f)

# Combine PMS-matched users for UK and Ireland
pms_matched_users = set(matched_users_data.get("UK", []) + matched_users_data.get("Ireland", []))

# Define countries of a subgroup
target_countries = ["United Kingdom", "Ireland"]

# 1. Create an edge list (user, cluster, weight)
# user - source node
# cluster - target node
# weight - for frequency of co-occurrence
# and split by country
edge_counts = {country: defaultdict(int) for country in target_countries}
users_with_tags = {country: set() for country in target_countries}

for user, info in data.items():
    if user not in pms_matched_users:
        continue
        
    clusters = info.get("tag_clusters", [])
        
    country = info.get("demographics", {}).get("country")

    if country not in target_countries:
        continue
    
    for cluster in clusters:
        if cluster != "N/A":
            edge_counts[country][(user, cluster)] += 1
            users_with_tags[country].add(user)

def build_and_project_graph(country):
    # 2. Create a bipartite graph (2 types of nodes: Users & Clusters)
    # Input: nodes (source & target) & edge list
    B = nx.Graph()
    
    # Add nodes (Users & Clusters)
    users = set()
    clusters = set()
    
    for (user, cluster), weight in edge_counts[country].items():
        users.add(user)
        clusters.add(cluster)
        B.add_node(user, bipartite=0)  # users
        B.add_node(cluster, bipartite=1)  # clusters
        B.add_edge(user, cluster, weight=weight)
    
    # Show edge list
    edge_list = [(u, c, w) for (u, c), w in edge_counts[country].items()]
    df = pd.DataFrame(edge_list, columns=["user", "cluster", "weight"])
    print(df.head(5))
    
    # 3. Project to cluster-cluster co-occurrence network
    projected = nx.bipartite.weighted_projected_graph(B, clusters)
    
    # 4. Save the projected network edge list (cluster co-occurrence)
    cooccurrence_edges = [
        {"source": u, "target": v, "weight": d["weight"]}
        for u, v, d in projected.edges(data=True)
    ]

    file_name = os.path.join(output_path, f"cluster_co-occurrence_{country}.json")
    
    with open(file_name, "w", encoding="utf-8") as f:
        json.dump(cooccurrence_edges, f, indent=2)
    
    print(f"\nProjected cluster co-occurrence edges saved to: {file_name}")
    
    print(f"\nSummary for {country} - users:")
    # print(f"Total users in file: {len(data)}")
    print(f"Users with at least one cluster: {len(users_with_tags[country])}")
    print(f"Total user-cluster edges: {len(edge_counts[country])}")
    print(f"Unique clusters: {len(clusters)}")
    print(f"Edges in projected cluster-cluster graph: {projected.number_of_edges()}")

    return df

# Run for each country
df_us = build_and_project_graph("United Kingdom")
df_canada = build_and_project_graph("Ireland")
# Out:
#               user                              cluster  weight
# 0    Vontrapfamily              Cardiovascular Diseases       1
# 1    Vontrapfamily        Lifestyle, Diet & Supplements       2
# 2  worthytobeloved  Mental Health & Emotional Wellbeing       7
# 3  worthytobeloved    Pain & Musculoskeletal Conditions       2
# 4  worthytobeloved           Dermatology & Skin-Related       1
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\country\UK - Ireland\cluster_co-occurrence_United Kingdom.json
#
# Summary for United Kingdom - users:
# Users with at least one cluster: 33
# Total user-cluster edges: 94
# Unique clusters: 18
# Edges in projected cluster-cluster graph: 61
#          user                                            cluster  weight
# 0  JezzaJezza                            Cardiovascular Diseases       6
# 1  JezzaJezza                      Lifestyle, Diet & Supplements       7
# 2  JezzaJezza                 Medications & Treatment Monitoring       1
# 3  JezzaJezza  Reproductive & Sexual Health (Women's Health &...       1
# 4  JezzaJezza                Mental Health & Emotional Wellbeing       1
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\country\UK - Ireland\cluster_co-occurrence_Ireland.json
#
# Summary for Ireland - users:
# Users with at least one cluster: 33
# Total user-cluster edges: 95
# Unique clusters: 17
# Edges in projected cluster-cluster graph: 56

# %% [markdown]
# ### Demographics Group: Age

# %% [markdown]
# on whole sample for now
#
# 1. 18-30 (way less than in any group)
# 2. 30-50
# 3. 50-70
# 4. 70+

# %%
import json
import os
import networkx as nx
from collections import defaultdict, Counter
import pandas as pd

base_dir = os.path.abspath("..")
file_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "general_profiles_data_with_tag_clusters.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics", "age")

# Load file with profiles & tag-to-cluster mapping
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Define age group of a user
def get_age_group(age):
    try:
        age = int(age)
        if age < 18:
            return None
        elif 18 <= age <= 30:
            return "18-30"
        elif 30 < age <= 50:
            return "30-50"
        elif 50 < age <= 70:
            return "50-70"
        else:
            return "70+"
    except:
        return None

age_groups = defaultdict(dict)

# Group users by age group
for user, info in data.items():
    # clusters = info.get("tag_clusters", [])
    age = info.get("demographics", {}).get("age", "N/A")    
    group = get_age_group(age)

    if group:
        age_groups[group][user] = info

def build_and_project_graph(group_name, group_data):
    # 1. Create an edge list (user, cluster, weight)
    # user - source node
    # cluster - target node
    # weight - for frequency of co-occurrence
    edge_counts = defaultdict(int)
    users_with_tags = set()

    for user, info in group_data.items():
        clusters = info.get("tag_clusters", [])
        
        for cluster in clusters:
            if cluster != "N/A":
                edge_counts[(user, cluster)] += 1
                users_with_tags.add(user)
    
    # 2. Create a bipartite graph (2 types of nodes: Users & Clusters)
    # Input: nodes (source & target) & edge list
    B = nx.Graph()
    
    # Add nodes (Users & Clusters)
    users = set()
    clusters = set()
    
    for (user, cluster), weight in edge_counts.items():
        users.add(user)
        clusters.add(cluster)
        B.add_node(user, bipartite=0)  # users
        B.add_node(cluster, bipartite=1)  # clusters
        B.add_edge(user, cluster, weight=weight)
    
    # Visualize an edge list
    edge_list = [(u, c, w) for (u, c), w in edge_counts.items()]
    df = pd.DataFrame(edge_list, columns=["user", "cluster", "weight"])
    print(df.head(10))
    
    # 3. Project to cluster-cluster co-occurrence network
    projected = nx.bipartite.weighted_projected_graph(B, clusters)
    
    # 4. Save the projected network edge list (cluster co-occurrence)
    cooccurrence_edges = [
        {"source": u, "target": v, "weight": d["weight"]}
        for u, v, d in projected.edges(data=True)
    ]

    file_name = os.path.join(output_path, f"cluster_co-occurrence_{group_name}.json")
    
    with open(file_name, "w", encoding="utf-8") as f:
        json.dump(cooccurrence_edges, f, indent=2)
    
    print(f"\nProjected cluster co-occurrence edges saved to: {file_name}")
    
    print(f"\nSummary for {group}- users:")
    print(f"Total users in file: {len(group_data)}")
    print(f"Users with at least one cluster: {len(users_with_tags)}")
    print(f"Total user-cluster edges: {len(edge_counts)}")
    print(f"Unique clusters: {len(clusters)}")
    print(f"Edges in projected cluster-cluster graph: {projected.number_of_edges()}")

# Run for each age group
for group, users in age_groups.items():
    build_and_project_graph(group, users)
# Out:
#           user                                            cluster  weight
# 0   Tumorboy20                             Neurological Disorders       2
# 1    Rubytunes                            Cardiovascular Diseases       2
# 2    Rubytunes     Digestive Health (Gastrointestinal Conditions)       1
# 3    Rubytunes                         Dermatology & Skin-Related       1
# 4    Pastamama                                Autoimmune Diseases       2
# 5    Pastamama                      Lifestyle, Diet & Supplements       4
# 6    Pastamama  Reproductive & Sexual Health (Women's Health &...       1
# 7    Pastamama                Mental Health & Emotional Wellbeing       1
# 8  Kendalghost                            Cardiovascular Diseases       1
# 9  Kendalghost                      Lifestyle, Diet & Supplements       2
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\age\cluster_co-occurrence_50-70.json
#
# Summary for 50-70- users:
# Total users in file: 1587
# Users with at least one cluster: 1587
# Total user-cluster edges: 4764
# Unique clusters: 23
# Edges in projected cluster-cluster graph: 243
#               user                                            cluster  weight
# 0   mubashrashafiq                      Lifestyle, Diet & Supplements       1
# 1            Elsx0                Respiratory Conditions & Treatments       2
# 2   maddylovesball                Mental Health & Emotional Wellbeing       3
# 3   maddylovesball                             Neurological Disorders       1
# 4   maddylovesball                      Lifestyle, Diet & Supplements       3
# 5        Dinkulgag                Mental Health & Emotional Wellbeing       4
# 6        Dinkulgag                 Medications & Treatment Monitoring       1
# 7  jadesallywillow                Mental Health & Emotional Wellbeing       4
# 8      ToxicSpikes                Mental Health & Emotional Wellbeing       3
# 9           nchauf  Reproductive & Sexual Health (Women's Health &...       1
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\age\cluster_co-occurrence_18-30.json
#
# Summary for 18-30- users:
# Total users in file: 380
# Users with at least one cluster: 380
# Total user-cluster edges: 970
# Unique clusters: 22
# Edges in projected cluster-cluster graph: 156
#            user                                            cluster  weight
# 0  Lizzyanne567                      Lifestyle, Diet & Supplements       3
# 1  Lizzyanne567  Reproductive & Sexual Health (Women's Health &...       1
# 2   707twitcher                             Neurological Disorders       1
# 3   707twitcher                  Pain & Musculoskeletal Conditions       1
# 4   707twitcher                Mental Health & Emotional Wellbeing       2
# 5    HipHop1972                             Neurological Disorders       3
# 6    HipHop1972                  Pain & Musculoskeletal Conditions       1
# 7    HipHop1972                Mental Health & Emotional Wellbeing       1
# 8      GeoPam28                                  Cancer & Oncology       2
# 9      GeoPam28  Reproductive & Sexual Health (Women's Health &...       1
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\age\cluster_co-occurrence_70+.json
#
# Summary for 70+- users:
# Total users in file: 759
# Users with at least one cluster: 759
# Total user-cluster edges: 2348
# Unique clusters: 23
# Edges in projected cluster-cluster graph: 234
#           user                                            cluster  weight
# 0       Anasjk                Mental Health & Emotional Wellbeing       1
# 1    kirks2092                             Neurological Disorders       1
# 2    kirks2092  Reproductive & Sexual Health (Women's Health &...       1
# 3  JenniferSee  Reproductive & Sexual Health (Women's Health &...       1
# 4  JenniferSee                Mental Health & Emotional Wellbeing       1
# 5       AnnaHU                Mental Health & Emotional Wellbeing       1
# 6       AnnaHU  Reproductive & Sexual Health (Women's Health &...       2
# 7       AnnaHU                      Lifestyle, Diet & Supplements       1
# 8    Paulo1976                                  Cancer & Oncology       1
# 9    Paulo1976  Reproductive & Sexual Health (Women's Health &...       1
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\general_patterns\demographics\age\cluster_co-occurrence_30-50.json
#
# Summary for 30-50- users:
# Total users in file: 1023
# Users with at least one cluster: 1023
# Total user-cluster edges: 2761
# Unique clusters: 23
# Edges in projected cluster-cluster graph: 242

# %% [markdown]
# ### Demographics Group: Ethnicity

# %% [raw]
# on whole sample for now

# %% [markdown]
# #### white | asian | black | latino

# %%
import json
import os
import networkx as nx
from collections import defaultdict, Counter
import pandas as pd

base_dir = os.path.abspath("..")
file_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "general_profiles_data_with_tag_clusters.json")
output_path = os.path.join(base_dir, "data", "bipartite_network", "general_patterns", "demographics", "ethnicity")

# Load file with profiles & tag-to-cluster mapping
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Define ethnicities of a subgroup
target_ethnicities = ["white", "asian", "black", "latino"]

# 1. Create an edge list (user, cluster, weight)
# user - source node
# cluster - target node
# weight - for frequency of co-occurrence
# and split by country
edge_counts = {ethnicity: defaultdict(int) for ethnicity in target_ethnicities}
users_with_tags = {ethnicity: set() for ethnicity in target_ethnicities}

for user, info in data.items():
    clusters = info.get("tag_clusters", [])
    ethnicity = info.get("demographics", {}).get("ethnicity").lower()

    if ethnicity not in target_ethnicities:
        continue
    
    for cluster in clusters:
        if cluster != "N/A":
            edge_counts[ethnicity][(user, cluster)] += 1
            users_with_tags[ethnicity].add(user)

def build_and_project_graph(ethnicity):
    # 2. Create a bipartite graph (2 types of nodes: Users & Clusters)
    # Input: nodes (source & target) & edge list
    B = nx.Graph()
    
    # Add nodes (Users & Clusters)
    users = set()
    clusters = set()
    
    for (user, cluster), weight in edge_counts[ethnicity].items():
        users.add(user)
        clusters.add(cluster)
        B.add_node(user, bipartite=0)  # users
        B.add_node(cluster, bipartite=1)  # clusters
        B.add_edge(user, cluster, weight=weight)
    
    # Show edge list
    edge_list = [(u, c, w) for (u, c), w in edge_counts[ethnicity].items()]
    df = pd.DataFrame(edge_list, columns=["user", "cluster", "weight"])
    print(df.head(5))
    
    # 3. Project to cluster-cluster co-occurrence network
    projected = nx.bipartite.weighted_projected_graph(B, clusters)
    
    # 4. Save the projected network edge list (cluster co-occurrence)
    cooccurrence_edges = [
        {"source": u, "target": v, "weight": d["weight"]}
        for u, v, d in projected.edges(data=True)
    ]

    file_name = os.path.join(output_path, f"cluster_co-occurrence_{ethnicity}.json")
    
    with open(file_name, "w", encoding="utf-8") as f:
        json.dump(cooccurrence_edges, f, indent=2)
    
    print(f"\nProjected cluster co-occurrence edges saved to: {file_name}")
    
    print(f"\nSummary for {ethnicity} - users:")
    # print(f"Total users in file: {len(data)}")
    print(f"Users with at least one cluster: {len(users_with_tags[ethnicity])}")
    print(f"Total user-cluster edges: {len(edge_counts[ethnicity])}")
    print(f"Unique clusters: {len(clusters)}")
    print(f"Edges in projected cluster-cluster graph: {projected.number_of_edges()}")

    return df

# Run for each country
df_white = build_and_project_graph("white")
df_asian = build_and_project_graph("asian")
df_black = build_and_project_graph("black")
df_latino = build_and_project_graph("latino")
# Out:
#          user                          cluster  weight
# 0  Wegeners88              Autoimmune Diseases       1
# 1  Wegeners88  Metabolic & Endocrine Disorders       2
# 2  Wegeners88    Preventive Health & Screening       1
# 3  Wegeners88          Cardiovascular Diseases       2
# 4  Wegeners88     Hematology & Blood Disorders       1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 85
#      82     return df
#      84 # Run for each country
# ---> 85 df_white = build_and_project_graph("white")
#      86 df_asian = build_and_project_graph("asian")
#      87 df_black = build_and_project_graph("black")
#
# Cell In[3], line 70, in build_and_project_graph(ethnicity)
#      63 cooccurrence_edges = [
#      64     {"source": u, "target": v, "weight": d["weight"]}
#      65     for u, v, d in projected.edges(data=True)
#      66 ]
#      68 file_name = os.path.join(output_path, f"cluster_co-occurrence_{ethnicity}.json")
# ---> 70 with open(file_name, "w", encoding="utf-8") as f:
#      71     json.dump(cooccurrence_edges, f, indent=2)
#      73 print(f"\nProjected cluster co-occurrence edges saved to: {file_name}")
#
# File ~\thesis\tum-thesis\gensim_env\Lib\site-packages\IPython\core\interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\nastya\\thesis\\tum-thesis\\data\\bipartite_network\\general_patterns\\demographics\\ethnicity\\white - asian - black - latino\\cluster_co-occurrence_white.json'

# %% [markdown]
# ## 2. Community-Specific Patterns

# %% [markdown]
# ### Create for EACH community a separate network:
# coachtrip | repiratory desease | 3 (weight) | +1 new col: comm_url

# %%
import json
import os
import networkx as nx
from collections import defaultdict
import pandas as pd

base_dir = os.path.abspath("..")
input_path = os.path.join(base_dir, "data", "bipartite_network", "community-specific_patterns", "profiles_by_comm_data_with_tag_clusters.json")
output_dir = os.path.join(base_dir, "data", "bipartite_network", "community-specific_patterns", "cluster_co-occurrence_edges_by_comm")
os.makedirs(output_dir, exist_ok=True)

# Load file with profiles by community & tag-to-cluster mapping
with open(input_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# total_communities = len(data)
valid_communities = 0
skipped_communities = 0

# Create for EACH community a SEPARATE network
for comm_url, users_dict in data.items():
    print(f"\nProcessing community: {comm_url}")
    edge_counts = defaultdict(int)
    
    # # 1. Create an edge list (user, cluster, weight)
    # user - source node
    # cluster - target node
    # weight - for frequency of co-occurrence
    for user, profile in users_dict.items():
        clusters = profile.get("tag_clusters", [])
        for cluster in clusters:
            if cluster != "N/A":
                edge_counts[(user, cluster)] += 1

    # Skip community where members have not set any tags
    if not edge_counts:
        print(f"Skipping {comm_url}: no user-cluster edges.")
        skipped_communities += 1
        continue
    valid_communities += 1
    
    # 2. Create a bipartite graph (2 types of nodes: Users & Clusters)
    # Input: nodes (source & target) & edge list
    B = nx.Graph()

    # Add nodes (Users & Clusters)
    users = set()
    clusters = set()
    
    for (user, cluster), weight in edge_counts.items():
        users.add(user)
        clusters.add(cluster)
        B.add_node(user, bipartite=0)
        B.add_node(cluster, bipartite=1)
        B.add_edge(user, cluster, weight=weight)
    
    # Visualize an edge list
    edge_list = [(user, cluster, weight, comm_url) for (user, cluster), weight in edge_counts.items()]
    df = pd.DataFrame(edge_list, columns=["user", "cluster", "weight", "comm_url"])
    print(df.head(10))
    
    # 3. Project to cluster-cluster co-occurrence network
    projected = nx.bipartite.weighted_projected_graph(B, clusters)
    
    # 4. Save the projected network edge list (cluster co-occurrence)
    cooccurrence_edges = [
        {"source": u, "target": v, "weight": d["weight"]}
        for u, v, d in projected.edges(data=True)
    ]
    
    # Get filename from "comm_url" (e.g. "/pmrgcauk" -> "pmrgcauk.json")
    community_filename = comm_url.strip("/").replace("/", "_") + "_co-occurrence.json"
    output_path = os.path.join(output_dir, community_filename)

    with open(output_path, "w", encoding="utf-8") as f_out:
        json.dump(cooccurrence_edges, f_out, indent=2)

    print(f"\nProjected cluster co-occurrence edges saved to: {output_path}")
    
print("\nSummary:")
print(f"Total communities: {len(data)}")
print(f"Communities with tags: {valid_communities}")
print(f"Communities skipped (no tags): {skipped_communities}")
# Out:
# Processing community: /pmrgcauk
#             user                                            cluster  weight  \
# 0     DorsetLady                  Pain & Musculoskeletal Conditions       5
# 1     DorsetLady                                Autoimmune Diseases       1
# 2     DorsetLady                    Metabolic & Endocrine Disorders       1
# 3     DorsetLady                      Lifestyle, Diet & Supplements       1
# 4     DorsetLady  Reproductive & Sexual Health (Women's Health &...       1
# 5  SheffieldJane                  Pain & Musculoskeletal Conditions       4
# 6  SheffieldJane                    Metabolic & Endocrine Disorders       5
# 7  SheffieldJane                                Autoimmune Diseases       3
# 8  SheffieldJane                      Lifestyle, Diet & Supplements       1
# 9  SheffieldJane                            Cardiovascular Diseases       3
#
#     comm_url
# 0  /pmrgcauk
# 1  /pmrgcauk
# 2  /pmrgcauk
# 3  /pmrgcauk
# 4  /pmrgcauk
# 5  /pmrgcauk
# 6  /pmrgcauk
# 7  /pmrgcauk
# 8  /pmrgcauk
# 9  /pmrgcauk
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\pmrgcauk_co-occurrence.json
#
# Processing community: /bhf
#         user                                         cluster  weight comm_url
# 0  MichaelJH               Pain & Musculoskeletal Conditions       1     /bhf
# 1  MichaelJH                 Metabolic & Endocrine Disorders       1     /bhf
# 2  MichaelJH                          Neurological Disorders       1     /bhf
# 3  MichaelJH                         Cardiovascular Diseases       1     /bhf
# 4  Milkfairy                          Neurological Disorders       2     /bhf
# 5  Milkfairy              Medications & Treatment Monitoring       3     /bhf
# 6  Milkfairy                         Cardiovascular Diseases      12     /bhf
# 7  Milkfairy               Pain & Musculoskeletal Conditions       1     /bhf
# 8  Milkfairy  Digestive Health (Gastrointestinal Conditions)       1     /bhf
# 9  Milkfairy             Respiratory Conditions & Treatments       1     /bhf
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\bhf_co-occurrence.json
#
# Processing community: /care-community
#            user                                            cluster  weight  \
# 0  Activity2004                    Metabolic & Endocrine Disorders       1
# 1         klr31                  Pain & Musculoskeletal Conditions       1
# 2         klr31                    Metabolic & Endocrine Disorders       1
# 3         klr31                             Neurological Disorders       1
# 4         klr31                      Lifestyle, Diet & Supplements       2
# 5         klr31  Reproductive & Sexual Health (Women's Health &...       1
# 6     secrets22                Mental Health & Emotional Wellbeing       4
# 7     secrets22                    Metabolic & Endocrine Disorders       1
# 8     secrets22                  Pain & Musculoskeletal Conditions       1
# 9    katieoxo60                  Pain & Musculoskeletal Conditions       2
#
#           comm_url
# 0  /care-community
# 1  /care-community
# 2  /care-community
# 3  /care-community
# 4  /care-community
# 5  /care-community
# 6  /care-community
# 7  /care-community
# 8  /care-community
# 9  /care-community
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\care-community_co-occurrence.json
#
# Processing community: /asthmalunguk-lung
#          user                                         cluster  weight  \
# 0     sassy59             Respiratory Conditions & Treatments       1
# 1     sassy59                 Metabolic & Endocrine Disorders       1
# 2    Caspiana                          Renal & Liver Diseases       1
# 3        Izb1                             Autoimmune Diseases       1
# 4        Izb1             Respiratory Conditions & Treatments       1
# 5        Izb1  Digestive Health (Gastrointestinal Conditions)       1
# 6       peege             Respiratory Conditions & Treatments       6
# 7       peege                          Neurological Disorders       1
# 8       peege                         Cardiovascular Diseases       1
# 9  katieoxo60               Pain & Musculoskeletal Conditions       2
#
#              comm_url
# 0  /asthmalunguk-lung
# 1  /asthmalunguk-lung
# 2  /asthmalunguk-lung
# 3  /asthmalunguk-lung
# 4  /asthmalunguk-lung
# 5  /asthmalunguk-lung
# 6  /asthmalunguk-lung
# 7  /asthmalunguk-lung
# 8  /asthmalunguk-lung
# 9  /asthmalunguk-lung
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\asthmalunguk-lung_co-occurrence.json
#
# Processing community: /thyroiduk
#            user                                            cluster  weight  \
# 0    SlowDragon                    Metabolic & Endocrine Disorders       3
# 1    SlowDragon                      Lifestyle, Diet & Supplements       2
# 2    SlowDragon     Digestive Health (Gastrointestinal Conditions)       1
# 3    SlowDragon                                Autoimmune Diseases       1
# 4         shaws                  Pain & Musculoskeletal Conditions       1
# 5      helvella                  Pain & Musculoskeletal Conditions       1
# 6  SeasideSusie                    Metabolic & Endocrine Disorders       1
# 7     humanbean  Reproductive & Sexual Health (Women's Health &...       2
# 8     humanbean                    Metabolic & Endocrine Disorders       1
# 9    tattybogle                    Metabolic & Endocrine Disorders       2
#
#      comm_url
# 0  /thyroiduk
# 1  /thyroiduk
# 2  /thyroiduk
# 3  /thyroiduk
# 4  /thyroiduk
# 5  /thyroiduk
# 6  /thyroiduk
# 7  /thyroiduk
# 8  /thyroiduk
# 9  /thyroiduk
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\thyroiduk_co-occurrence.json
#
# Processing community: /vasculitis-uk
#          user                          cluster  weight        comm_url
# 0  John_Mills              Autoimmune Diseases       3  /vasculitis-uk
# 1  John_Mills                Cancer & Oncology       3  /vasculitis-uk
# 2  John_Mills  Metabolic & Endocrine Disorders       1  /vasculitis-uk
# 3     AndrewT  Metabolic & Endocrine Disorders       1  /vasculitis-uk
# 4     AndrewT              Autoimmune Diseases       2  /vasculitis-uk
# 5     AndrewT           Neurological Disorders       1  /vasculitis-uk
# 6     AndrewT           Renal & Liver Diseases       1  /vasculitis-uk
# 7     AndrewT       Dermatology & Skin-Related       1  /vasculitis-uk
# 8     AndrewT    Lifestyle, Diet & Supplements       2  /vasculitis-uk
# 9  vivdunstan              Autoimmune Diseases       1  /vasculitis-uk
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\vasculitis-uk_co-occurrence.json
#
# Processing community: /meningioma-support
#           user                                            cluster  weight  \
# 0       Lytham                             Neurological Disorders       1
# 1    Paper2021                             Neurological Disorders       3
# 2    Paper2021                                  Cancer & Oncology       1
# 3  jasonoliv34                             Neurological Disorders       1
# 4  jasonoliv34            Procedures, Surgeries & Medical Devices       1
# 5  jasonoliv34  Reproductive & Sexual Health (Women's Health &...       1
# 6  jasonoliv34                      Lifestyle, Diet & Supplements       3
# 7  jasonoliv34                Mental Health & Emotional Wellbeing       1
# 8    Cast_away                             Neurological Disorders       2
# 9    Cast_away                      Lifestyle, Diet & Supplements       2
#
#               comm_url
# 0  /meningioma-support
# 1  /meningioma-support
# 2  /meningioma-support
# 3  /meningioma-support
# 4  /meningioma-support
# 5  /meningioma-support
# 6  /meningioma-support
# 7  /meningioma-support
# 8  /meningioma-support
# 9  /meningioma-support
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\meningioma-support_co-occurrence.json
#
# Processing community: /healthyeating
#               user                                         cluster  weight  \
# 0     Activity2004                 Metabolic & Endocrine Disorders       1
# 1  Kitten-whiskers                 Metabolic & Endocrine Disorders       2
# 2  Kitten-whiskers               Pain & Musculoskeletal Conditions       1
# 3  Kitten-whiskers  Digestive Health (Gastrointestinal Conditions)       1
# 4  Kitten-whiskers                             Autoimmune Diseases       1
# 5  Kitten-whiskers                   Lifestyle, Diet & Supplements       1
# 6  Kitten-whiskers             Mental Health & Emotional Wellbeing       1
# 7     Rachmaninov2               Pain & Musculoskeletal Conditions       3
# 8     Rachmaninov2                             Autoimmune Diseases       2
# 9     Rachmaninov2  Digestive Health (Gastrointestinal Conditions)       1
#
#          comm_url
# 0  /healthyeating
# 1  /healthyeating
# 2  /healthyeating
# 3  /healthyeating
# 4  /healthyeating
# 5  /healthyeating
# 6  /healthyeating
# 7  /healthyeating
# 8  /healthyeating
# 9  /healthyeating
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\healthyeating_co-occurrence.json
#
# Processing community: /icusteps
#               user                              cluster  weight   comm_url
# 0           Sepsur                    Cancer & Oncology       2  /icusteps
# 1           Sepsur   Infectious & Communicable Diseases       9  /icusteps
# 2           Sepsur      Metabolic & Endocrine Disorders       2  /icusteps
# 3           Sepsur               Neurological Disorders       2  /icusteps
# 4           Sepsur  Respiratory Conditions & Treatments       1  /icusteps
# 5           Sepsur        Preventive Health & Screening       1  /icusteps
# 6           Sepsur        Lifestyle, Diet & Supplements       1  /icusteps
# 7           Sepsur  Mental Health & Emotional Wellbeing       1  /icusteps
# 8  FamilyHistorian                  Autoimmune Diseases       1  /icusteps
# 9  FamilyHistorian                    Cancer & Oncology       1  /icusteps
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\icusteps_co-occurrence.json
#
# Processing community: /adhd-parents
#               user                              cluster  weight       comm_url
# 0    Onthemove1971               Neurological Disorders       1  /adhd-parents
# 1        Mamamichl  Mental Health & Emotional Wellbeing       6  /adhd-parents
# 2        Mamamichl          Patient Support & Education       1  /adhd-parents
# 3         Cjkchamp  Mental Health & Emotional Wellbeing       1  /adhd-parents
# 4         Aspen797               Neurological Disorders       1  /adhd-parents
# 5      SurvivorFan  Mental Health & Emotional Wellbeing       2  /adhd-parents
# 6          Klmamma  Mental Health & Emotional Wellbeing       2  /adhd-parents
# 7        Redpanda5  Mental Health & Emotional Wellbeing       1  /adhd-parents
# 8  KarenADHDWeekly  Mental Health & Emotional Wellbeing       1  /adhd-parents
# 9         STEM_Dad  Mental Health & Emotional Wellbeing       9  /adhd-parents
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\adhd-parents_co-occurrence.json
#
# Processing community: /cure-parkinsons
#            user                          cluster  weight          comm_url
# 0    MBAnderson           Neurological Disorders       1  /cure-parkinsons
# 1  Bolt_Upright  Metabolic & Endocrine Disorders       1  /cure-parkinsons
# 2      chartist    Lifestyle, Diet & Supplements       1  /cure-parkinsons
# 3         Hikoi           Neurological Disorders       1  /cure-parkinsons
# 4  WinnieThePoo           Neurological Disorders       2  /cure-parkinsons
# 5          Gioc           Neurological Disorders       1  /cure-parkinsons
# 6      Farooqji           Neurological Disorders       1  /cure-parkinsons
# 7       MarionP           Neurological Disorders       2  /cure-parkinsons
# 8      jeeves19           Neurological Disorders       1  /cure-parkinsons
# 9      jeeves19    Preventive Health & Screening       1  /cure-parkinsons
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\cure-parkinsons_co-occurrence.json
#
# Processing community: /glaucoma-uk
#         user                                            cluster  weight  \
# 0  Beecalmed                                Eye & Vision Health       1
# 1    Wales99                Mental Health & Emotional Wellbeing       2
# 2    Wales99                  Pain & Musculoskeletal Conditions       1
# 3    Wales99                            Cardiovascular Diseases       3
# 4    Wales99                             Neurological Disorders       2
# 5    Wales99                                Eye & Vision Health       2
# 6    Wales99                      Lifestyle, Diet & Supplements       3
# 7    Wales99  Reproductive & Sexual Health (Women's Health &...       1
# 8  muddledme                                Eye & Vision Health       1
# 9  muddledme            Procedures, Surgeries & Medical Devices       1
#
#        comm_url
# 0  /glaucoma-uk
# 1  /glaucoma-uk
# 2  /glaucoma-uk
# 3  /glaucoma-uk
# 4  /glaucoma-uk
# 5  /glaucoma-uk
# 6  /glaucoma-uk
# 7  /glaucoma-uk
# 8  /glaucoma-uk
# 9  /glaucoma-uk
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\glaucoma-uk_co-occurrence.json
#
# Processing community: /sruk
#        user                                         cluster  weight comm_url
# 0  OldTed60                 Metabolic & Endocrine Disorders       1    /sruk
# 1  OldTed60               Pain & Musculoskeletal Conditions       2    /sruk
# 2  OldTed60                             Autoimmune Diseases       4    /sruk
# 3  OldTed60                               Cancer & Oncology       3    /sruk
# 4  OldTed60                         Cardiovascular Diseases       1    /sruk
# 5  OldTed60  Digestive Health (Gastrointestinal Conditions)       3    /sruk
# 6  OldTed60               Rare Diseases & Genetic Disorders       1    /sruk
# 7    EOLHPC                             Autoimmune Diseases       5    /sruk
# 8    EOLHPC                 Metabolic & Endocrine Disorders       1    /sruk
# 9    EOLHPC               Pain & Musculoskeletal Conditions       5    /sruk
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\sruk_co-occurrence.json
#
# Processing community: /prostate-cancer-community
#          user                                            cluster  weight  \
# 0     j-o-h-n                                  Cancer & Oncology       1
# 1   maley2711                                  Cancer & Oncology       1
# 2   janebob99                                  Cancer & Oncology       1
# 3   janebob99  Reproductive & Sexual Health (Women's Health &...       1
# 4   janebob99                      Lifestyle, Diet & Supplements       1
# 5    Justfor_                                  Cancer & Oncology       1
# 6  Magnus1964                                  Cancer & Oncology       8
# 7  Magnus1964  Reproductive & Sexual Health (Women's Health &...       1
# 8  Magnus1964                         Dermatology & Skin-Related       1
# 9   dadzone43                                  Cancer & Oncology       2
#
#                      comm_url
# 0  /prostate-cancer-community
# 1  /prostate-cancer-community
# 2  /prostate-cancer-community
# 3  /prostate-cancer-community
# 4  /prostate-cancer-community
# 5  /prostate-cancer-community
# 6  /prostate-cancer-community
# 7  /prostate-cancer-community
# 8  /prostate-cancer-community
# 9  /prostate-cancer-community
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\prostate-cancer-community_co-occurrence.json
#
# Processing community: /advanced-prostate-cancer
#          user                                            cluster  weight  \
# 0     j-o-h-n                                  Cancer & Oncology       1
# 1     Kaliber                                  Cancer & Oncology       4
# 2   pjoshea13                                  Cancer & Oncology       1
# 3     tango65                                  Cancer & Oncology       1
# 4      dockam                                  Cancer & Oncology       3
# 5      dockam                    Metabolic & Endocrine Disorders       1
# 6      dockam  Reproductive & Sexual Health (Women's Health &...       2
# 7      dockam                 Medications & Treatment Monitoring       1
# 8      dockam                      Lifestyle, Diet & Supplements       3
# 9  Magnus1964                                  Cancer & Oncology       8
#
#                     comm_url
# 0  /advanced-prostate-cancer
# 1  /advanced-prostate-cancer
# 2  /advanced-prostate-cancer
# 3  /advanced-prostate-cancer
# 4  /advanced-prostate-cancer
# 5  /advanced-prostate-cancer
# 6  /advanced-prostate-cancer
# 7  /advanced-prostate-cancer
# 8  /advanced-prostate-cancer
# 9  /advanced-prostate-cancer
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\advanced-prostate-cancer_co-occurrence.json
#
# Processing community: /ovacome
#         user                                            cluster  weight  \
# 0  Katmal-UK                                  Cancer & Oncology       1
# 1      Lyndy                                Autoimmune Diseases       1
# 2      Lyndy                                  Cancer & Oncology       1
# 3      Lyndy                  Pain & Musculoskeletal Conditions       2
# 4   wendydee                                  Cancer & Oncology       1
# 5   wendydee  Reproductive & Sexual Health (Women's Health &...       2
# 6   Cropcrop                                  Cancer & Oncology       4
# 7   Cropcrop                            Cardiovascular Diseases       2
# 8   Cropcrop                    Metabolic & Endocrine Disorders       1
# 9   Cropcrop                 Medications & Treatment Monitoring       1
#
#    comm_url
# 0  /ovacome
# 1  /ovacome
# 2  /ovacome
# 3  /ovacome
# 4  /ovacome
# 5  /ovacome
# 6  /ovacome
# 7  /ovacome
# 8  /ovacome
# 9  /ovacome
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\ovacome_co-occurrence.json
#
# Processing community: /asthmalunguk-asthma
#       user                                         cluster  weight  \
# 0  EmmaF91             Respiratory Conditions & Treatments      15
# 1  EmmaF91                 Metabolic & Endocrine Disorders       2
# 2  EmmaF91                   Preventive Health & Screening       1
# 3  EmmaF91  Digestive Health (Gastrointestinal Conditions)       2
# 4  EmmaF91                   Lifestyle, Diet & Supplements       2
# 5  EmmaF91                      Dermatology & Skin-Related       1
# 6  EmmaF91              Infectious & Communicable Diseases       2
# 7  EmmaF91              Medications & Treatment Monitoring       5
# 8  EmmaF91                            Allergy & Immunology       1
# 9  EmmaF91                             Eye & Vision Health       1
#
#                comm_url
# 0  /asthmalunguk-asthma
# 1  /asthmalunguk-asthma
# 2  /asthmalunguk-asthma
# 3  /asthmalunguk-asthma
# 4  /asthmalunguk-asthma
# 5  /asthmalunguk-asthma
# 6  /asthmalunguk-asthma
# 7  /asthmalunguk-asthma
# 8  /asthmalunguk-asthma
# 9  /asthmalunguk-asthma
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\asthmalunguk-asthma_co-occurrence.json
#
# Processing community: /dentistry-health-support
#             user                                            cluster  weight  \
# 0          dtech                                Autoimmune Diseases       1
# 1  Latics1989-90                  Pain & Musculoskeletal Conditions       1
# 2  Latics1989-90                             Renal & Liver Diseases       1
# 3   Ellie-Louise                    Metabolic & Endocrine Disorders       1
# 4       Madlegs1                             Neurological Disorders       1
# 5       Madlegs1                  Pain & Musculoskeletal Conditions       2
# 6       Madlegs1                        Substance Abuse & Addiction       1
# 7       Madlegs1                            Cardiovascular Diseases       2
# 8       Madlegs1  Reproductive & Sexual Health (Women's Health &...       1
# 9     Deylikekey                  Pain & Musculoskeletal Conditions       1
#
#                     comm_url
# 0  /dentistry-health-support
# 1  /dentistry-health-support
# 2  /dentistry-health-support
# 3  /dentistry-health-support
# 4  /dentistry-health-support
# 5  /dentistry-health-support
# 6  /dentistry-health-support
# 7  /dentistry-health-support
# 8  /dentistry-health-support
# 9  /dentistry-health-support
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\dentistry-health-support_co-occurrence.json
#
# Processing community: /afassociation
#             user                                            cluster  weight  \
# 0       CDreamer                  Pain & Musculoskeletal Conditions       2
# 1       CDreamer                            Cardiovascular Diseases       5
# 2       CDreamer                Mental Health & Emotional Wellbeing       1
# 3       CDreamer                Respiratory Conditions & Treatments       1
# 4       CDreamer                                Autoimmune Diseases       3
# 5  jeanjeannie50                            Cardiovascular Diseases       4
# 6  jeanjeannie50                      Lifestyle, Diet & Supplements       2
# 7         Ppiman                            Cardiovascular Diseases       7
# 8         Ppiman  Reproductive & Sexual Health (Women's Health &...       1
# 9         Ppiman                      Lifestyle, Diet & Supplements       1
#
#          comm_url
# 0  /afassociation
# 1  /afassociation
# 2  /afassociation
# 3  /afassociation
# 4  /afassociation
# 5  /afassociation
# 6  /afassociation
# 7  /afassociation
# 8  /afassociation
# 9  /afassociation
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\afassociation_co-occurrence.json
#
# Processing community: /psp
#                  user                                            cluster  \
# 0            Katiebow                             Neurological Disorders
# 1              daddyt                             Neurological Disorders
# 2              daddyt                Mental Health & Emotional Wellbeing
# 3              daddyt                 Medications & Treatment Monitoring
# 4              daddyt                      Lifestyle, Diet & Supplements
# 5              daddyt  Reproductive & Sexual Health (Women's Health &...
# 6  LuisRodicioRodicio                             Neurological Disorders
# 7  LuisRodicioRodicio                Mental Health & Emotional Wellbeing
# 8  LuisRodicioRodicio                      Lifestyle, Diet & Supplements
# 9            honjen43                    Metabolic & Endocrine Disorders
#
#    weight comm_url
# 0       1     /psp
# 1       4     /psp
# 2       3     /psp
# 3       1     /psp
# 4       2     /psp
# 5       1     /psp
# 6       1     /psp
# 7       1     /psp
# 8       1     /psp
# 9       2     /psp
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\psp_co-occurrence.json
#
# Processing community: /rlsuk
#          user                              cluster  weight comm_url
# 0  SueJohnson    Pain & Musculoskeletal Conditions       1   /rlsuk
# 1  SueJohnson               Neurological Disorders       1   /rlsuk
# 2      Joolsg               Neurological Disorders       5   /rlsuk
# 3      Joolsg                    Cancer & Oncology       1   /rlsuk
# 4      Joolsg    Pain & Musculoskeletal Conditions       4   /rlsuk
# 5      Joolsg  Mental Health & Emotional Wellbeing       1   /rlsuk
# 6      Joolsg   Medications & Treatment Monitoring       1   /rlsuk
# 7    Madlegs1               Neurological Disorders       1   /rlsuk
# 8    Madlegs1    Pain & Musculoskeletal Conditions       2   /rlsuk
# 9    Madlegs1          Substance Abuse & Addiction       1   /rlsuk
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\rlsuk_co-occurrence.json
#
# Processing community: /research
#        user                                            cluster  weight  \
# 0  Teaching                Mental Health & Emotional Wellbeing       6
# 1  Teaching                             Neurological Disorders       1
# 2  Teaching                      Lifestyle, Diet & Supplements       4
# 3  Teaching  Reproductive & Sexual Health (Women's Health &...       1
# 4  focused1                Mental Health & Emotional Wellbeing       1
# 5  focused1     Digestive Health (Gastrointestinal Conditions)       4
# 6  Vonnegut                             Neurological Disorders       1
# 7  Vonnegut                            Cardiovascular Diseases       4
# 8  Vonnegut     Digestive Health (Gastrointestinal Conditions)       3
# 9   Adlon57                Mental Health & Emotional Wellbeing       3
#
#     comm_url
# 0  /research
# 1  /research
# 2  /research
# 3  /research
# 4  /research
# 5  /research
# 6  /research
# 7  /research
# 8  /research
# 9  /research
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\research_co-occurrence.json
#
# Processing community: /abda
#       user                                         cluster  weight comm_url
# 0  Zuzu798                         Cardiovascular Diseases       3    /abda
# 1  Zuzu798                               Cancer & Oncology       3    /abda
# 2  Zuzu798                          Neurological Disorders       4    /abda
# 3  Zuzu798             Mental Health & Emotional Wellbeing       4    /abda
# 4  Zuzu798               Pain & Musculoskeletal Conditions       5    /abda
# 5  Zuzu798                 Metabolic & Endocrine Disorders       2    /abda
# 6  Zuzu798                             Autoimmune Diseases       2    /abda
# 7  Zuzu798                   Lifestyle, Diet & Supplements       2    /abda
# 8  Zuzu798  Digestive Health (Gastrointestinal Conditions)       1    /abda
# 9  Zuzu798              Medications & Treatment Monitoring       1    /abda
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\abda_co-occurrence.json
#
# Processing community: /behcetsuk
#       user                                         cluster  weight    comm_url
# 0  lesleyg                             Autoimmune Diseases       2  /behcetsuk
# 1  lesleyg                               Cancer & Oncology       1  /behcetsuk
# 2  lesleyg              Medications & Treatment Monitoring       1  /behcetsuk
# 3    Jaxxi                          Neurological Disorders       1  /behcetsuk
# 4    Jaxxi                             Autoimmune Diseases       2  /behcetsuk
# 5    Jaxxi               Pain & Musculoskeletal Conditions       1  /behcetsuk
# 6    Jaxxi                         Cardiovascular Diseases       1  /behcetsuk
# 7    Jaxxi  Digestive Health (Gastrointestinal Conditions)       2  /behcetsuk
# 8  Legomum                             Autoimmune Diseases       1  /behcetsuk
# 9   Sunset                             Autoimmune Diseases       1  /behcetsuk
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\behcetsuk_co-occurrence.json
#
# Processing community: /fibromyalgia-action-uk
#             user                              cluster  weight  \
# 0       rosewine    Pain & Musculoskeletal Conditions       3
# 1       rosewine  Respiratory Conditions & Treatments       1
# 2       rosewine  Mental Health & Emotional Wellbeing       1
# 3       rosewine              Cardiovascular Diseases       1
# 4  Fibrofoggiest      Metabolic & Endocrine Disorders       1
# 5  Fibrofoggiest               Neurological Disorders       4
# 6  Fibrofoggiest              Cardiovascular Diseases       1
# 7       Dizzytwo    Pain & Musculoskeletal Conditions       2
# 8       Dizzytwo              Cardiovascular Diseases       1
# 9     Mackembabe  Respiratory Conditions & Treatments       2
#
#                   comm_url
# 0  /fibromyalgia-action-uk
# 1  /fibromyalgia-action-uk
# 2  /fibromyalgia-action-uk
# 3  /fibromyalgia-action-uk
# 4  /fibromyalgia-action-uk
# 5  /fibromyalgia-action-uk
# 6  /fibromyalgia-action-uk
# 7  /fibromyalgia-action-uk
# 8  /fibromyalgia-action-uk
# 9  /fibromyalgia-action-uk
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\fibromyalgia-action-uk_co-occurrence.json
#
# Processing community: /cllsupport
#          user                                         cluster  weight  \
# 0  AussieNeil                               Cancer & Oncology       6
# 1  AussieNeil                             Autoimmune Diseases       1
# 2  AussieNeil  Digestive Health (Gastrointestinal Conditions)       3
# 3  AussieNeil               Pain & Musculoskeletal Conditions       2
# 4  AussieNeil              Medications & Treatment Monitoring       1
# 5     Newdawn                               Cancer & Oncology       1
# 6    SofiaDeo             Mental Health & Emotional Wellbeing       3
# 7    SofiaDeo                   Preventive Health & Screening       1
# 8    SofiaDeo               Pain & Musculoskeletal Conditions       1
# 9    SofiaDeo                               Cancer & Oncology       1
#
#       comm_url
# 0  /cllsupport
# 1  /cllsupport
# 2  /cllsupport
# 3  /cllsupport
# 4  /cllsupport
# 5  /cllsupport
# 6  /cllsupport
# 7  /cllsupport
# 8  /cllsupport
# 9  /cllsupport
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\cllsupport_co-occurrence.json
#
# Processing community: /quitsupport
#          user                                         cluster  weight  \
# 0   jillygirl             Respiratory Conditions & Treatments       2
# 1   jillygirl              Infectious & Communicable Diseases       1
# 2   jillygirl                               Cancer & Oncology       1
# 3   jillygirl         Procedures, Surgeries & Medical Devices       1
# 4   jillygirl  Digestive Health (Gastrointestinal Conditions)       1
# 5  Corrina125                   Lifestyle, Diet & Supplements       3
# 6    Arizona-                     Substance Abuse & Addiction       1
# 7    NewKaren                 Metabolic & Endocrine Disorders       2
# 8        Cloe                          Neurological Disorders       2
# 9    Polly-PV             Respiratory Conditions & Treatments       4
#
#        comm_url
# 0  /quitsupport
# 1  /quitsupport
# 2  /quitsupport
# 3  /quitsupport
# 4  /quitsupport
# 5  /quitsupport
# 6  /quitsupport
# 7  /quitsupport
# 8  /quitsupport
# 9  /quitsupport
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\quitsupport_co-occurrence.json
#
# Processing community: /womenshealth
#         user                                            cluster  weight  \
# 0  wobblybee                             Neurological Disorders       2
# 1  wobblybee                                Autoimmune Diseases       1
# 2   bantam12                    Metabolic & Endocrine Disorders       1
# 3   bantam12                            Cardiovascular Diseases       1
# 4    BadHare                  Pain & Musculoskeletal Conditions       1
# 5    BadHare                    Metabolic & Endocrine Disorders       1
# 6    BadHare                      Lifestyle, Diet & Supplements       1
# 7    BadHare  Reproductive & Sexual Health (Women's Health &...       1
# 8     Mia898                             Neurological Disorders       1
# 9     Mia898  Reproductive & Sexual Health (Women's Health &...       3
#
#         comm_url
# 0  /womenshealth
# 1  /womenshealth
# 2  /womenshealth
# 3  /womenshealth
# 4  /womenshealth
# 5  /womenshealth
# 6  /womenshealth
# 7  /womenshealth
# 8  /womenshealth
# 9  /womenshealth
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\womenshealth_co-occurrence.json
#
# Processing community: /pregnancy-parenting-support
#                  user                                            cluster  \
# 0                Seb9                      Lifestyle, Diet & Supplements
# 1                Seb9  Reproductive & Sexual Health (Women's Health &...
# 2              Annh17  Reproductive & Sexual Health (Women's Health &...
# 3              Annh17                      Lifestyle, Diet & Supplements
# 4            Afrohair  Reproductive & Sexual Health (Women's Health &...
# 5  Lizzielizzielizzie  Reproductive & Sexual Health (Women's Health &...
# 6            Tugsgirl                                Autoimmune Diseases
# 7            Tugsgirl                            Cardiovascular Diseases
# 8            Tugsgirl  Reproductive & Sexual Health (Women's Health &...
# 9              MissEd                                  Cancer & Oncology
#
#    weight                      comm_url
# 0       1  /pregnancy-parenting-support
# 1       1  /pregnancy-parenting-support
# 2       2  /pregnancy-parenting-support
# 3       2  /pregnancy-parenting-support
# 4       2  /pregnancy-parenting-support
# 5       1  /pregnancy-parenting-support
# 6       1  /pregnancy-parenting-support
# 7       2  /pregnancy-parenting-support
# 8       1  /pregnancy-parenting-support
# 9       1  /pregnancy-parenting-support
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\pregnancy-parenting-support_co-occurrence.json
#
# Processing community: /pelvicpain
#           user                                            cluster  weight  \
# 0   Konagirl60                  Pain & Musculoskeletal Conditions       2
# 1   Konagirl60            Procedures, Surgeries & Medical Devices       1
# 2   Konagirl60  Reproductive & Sexual Health (Women's Health &...       2
# 3   Konagirl60                             Neurological Disorders       3
# 4   Konagirl60                      Lifestyle, Diet & Supplements       2
# 5  kalecolbe12  Reproductive & Sexual Health (Women's Health &...       1
# 6      Alaine1                Mental Health & Emotional Wellbeing       5
# 7      Alaine1  Reproductive & Sexual Health (Women's Health &...       5
# 8      Alaine1                      Preventive Health & Screening       1
# 9      Alaine1                Respiratory Conditions & Treatments       1
#
#       comm_url
# 0  /pelvicpain
# 1  /pelvicpain
# 2  /pelvicpain
# 3  /pelvicpain
# 4  /pelvicpain
# 5  /pelvicpain
# 6  /pelvicpain
# 7  /pelvicpain
# 8  /pelvicpain
# 9  /pelvicpain
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\pelvicpain_co-occurrence.json
#
# Processing community: /eric
#              user                                            cluster  weight  \
# 0         Misty10                  Pain & Musculoskeletal Conditions       1
# 1         Misty10                      Preventive Health & Screening       1
# 2         Misty10     Digestive Health (Gastrointestinal Conditions)       7
# 3         Misty10  Reproductive & Sexual Health (Women's Health &...       1
# 4         Misty10                 Infectious & Communicable Diseases       1
# 5  Frustratedmum1     Digestive Health (Gastrointestinal Conditions)       1
# 6  14crosstitch14  Reproductive & Sexual Health (Women's Health &...       1
# 7  14crosstitch14                      Lifestyle, Diet & Supplements       1
# 8  14crosstitch14                        Patient Support & Education       1
# 9         StellaA                                  Cancer & Oncology       2
#
#   comm_url
# 0    /eric
# 1    /eric
# 2    /eric
# 3    /eric
# 4    /eric
# 5    /eric
# 6    /eric
# 7    /eric
# 8    /eric
# 9    /eric
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\eric_co-occurrence.json
#
# Processing community: /nras
#            user                              cluster  weight comm_url
# 0         sylvi                  Autoimmune Diseases       1    /nras
# 1         sylvi    Pain & Musculoskeletal Conditions       1    /nras
# 2         sylvi  Respiratory Conditions & Treatments       1    /nras
# 3   nomoreheels                  Autoimmune Diseases       2    /nras
# 4   nomoreheels              Cardiovascular Diseases       1    /nras
# 5       allanah                  Autoimmune Diseases       2    /nras
# 6    helixhelix                  Autoimmune Diseases       1    /nras
# 7     AgedCrone               Neurological Disorders       1    /nras
# 8     AgedCrone        Lifestyle, Diet & Supplements       2    /nras
# 9  Neonkittie17                  Autoimmune Diseases       1    /nras
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\nras_co-occurrence.json
#
# Processing community: /menshealth
#                 user                                            cluster  \
# 0             jaglad  Reproductive & Sexual Health (Women's Health &...
# 1             jaglad                 Medications & Treatment Monitoring
# 2  ToonBlastChampion                      Lifestyle, Diet & Supplements
# 3            xsevenx                                Eye & Vision Health
# 4            xsevenx                            Cardiovascular Diseases
# 5            xsevenx     Digestive Health (Gastrointestinal Conditions)
# 6            xsevenx  Reproductive & Sexual Health (Women's Health &...
# 7            xsevenx                                  Cancer & Oncology
# 8            xsevenx            Procedures, Surgeries & Medical Devices
# 9            xsevenx                      Lifestyle, Diet & Supplements
#
#    weight     comm_url
# 0       1  /menshealth
# 1       1  /menshealth
# 2       2  /menshealth
# 3       2  /menshealth
# 4       2  /menshealth
# 5       1  /menshealth
# 6       3  /menshealth
# 7       1  /menshealth
# 8       1  /menshealth
# 9       1  /menshealth
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\menshealth_co-occurrence.json
#
# Processing community: /diabetes-support
#             user                                            cluster  weight  \
# 0       Fernsmum                    Metabolic & Endocrine Disorders       6
# 1       Fernsmum                       Hematology & Blood Disorders       1
# 2       Fernsmum     Digestive Health (Gastrointestinal Conditions)       2
# 3  Southeastgirl                    Metabolic & Endocrine Disorders       3
# 4  Southeastgirl                            Cardiovascular Diseases       3
# 5  Southeastgirl                      Lifestyle, Diet & Supplements       1
# 6        Boxroad                    Metabolic & Endocrine Disorders       4
# 7        Boxroad     Digestive Health (Gastrointestinal Conditions)       4
# 8        Boxroad                            Cardiovascular Diseases       5
# 9        Boxroad  Reproductive & Sexual Health (Women's Health &...       3
#
#             comm_url
# 0  /diabetes-support
# 1  /diabetes-support
# 2  /diabetes-support
# 3  /diabetes-support
# 4  /diabetes-support
# 5  /diabetes-support
# 6  /diabetes-support
# 7  /diabetes-support
# 8  /diabetes-support
# 9  /diabetes-support
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\diabetes-support_co-occurrence.json
#
# Processing community: /arrhythmia-alliance-heart-failure
#          user                                            cluster  weight  \
# 0  TracyAdmin                            Cardiovascular Diseases       1
# 1     Lezzers                      Lifestyle, Diet & Supplements       2
# 2    Deejay62                            Cardiovascular Diseases       9
# 3    Deejay62                             Renal & Liver Diseases       2
# 4    Deejay62                    Metabolic & Endocrine Disorders       1
# 5    Deejay62                      Lifestyle, Diet & Supplements       2
# 6    Deejay62  Reproductive & Sexual Health (Women's Health &...       1
# 7   Mikey8119                            Cardiovascular Diseases       1
# 8   Mikey8119                      Preventive Health & Screening       1
# 9   Mikey8119  Reproductive & Sexual Health (Women's Health &...       1
#
#                              comm_url
# 0  /arrhythmia-alliance-heart-failure
# 1  /arrhythmia-alliance-heart-failure
# 2  /arrhythmia-alliance-heart-failure
# 3  /arrhythmia-alliance-heart-failure
# 4  /arrhythmia-alliance-heart-failure
# 5  /arrhythmia-alliance-heart-failure
# 6  /arrhythmia-alliance-heart-failure
# 7  /arrhythmia-alliance-heart-failure
# 8  /arrhythmia-alliance-heart-failure
# 9  /arrhythmia-alliance-heart-failure
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\arrhythmia-alliance-heart-failure_co-occurrence.json
#
# Processing community: /nkf-ckd
#            user                                            cluster  weight  \
# 0  Bassetmommer                             Renal & Liver Diseases       2
# 1  Bassetmommer                                Autoimmune Diseases       1
# 2  orangecity41                       Hematology & Blood Disorders       1
# 3  orangecity41                             Neurological Disorders       2
# 4  orangecity41                  Pain & Musculoskeletal Conditions       1
# 5  orangecity41                             Renal & Liver Diseases       1
# 6  orangecity41                    Metabolic & Endocrine Disorders       3
# 7  orangecity41                      Preventive Health & Screening       1
# 8  orangecity41  Reproductive & Sexual Health (Women's Health &...       1
# 9  orangecity41                      Lifestyle, Diet & Supplements       2
#
#    comm_url
# 0  /nkf-ckd
# 1  /nkf-ckd
# 2  /nkf-ckd
# 3  /nkf-ckd
# 4  /nkf-ckd
# 5  /nkf-ckd
# 6  /nkf-ckd
# 7  /nkf-ckd
# 8  /nkf-ckd
# 9  /nkf-ckd
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\nkf-ckd_co-occurrence.json
#
# Processing community: /nkf-dialysis
#            user                          cluster  weight       comm_url
# 0       RonZone           Renal & Liver Diseases       4  /nkf-dialysis
# 1       RonZone  Metabolic & Endocrine Disorders       1  /nkf-dialysis
# 2       RonZone    Lifestyle, Diet & Supplements       2  /nkf-dialysis
# 3     Jayhawker           Renal & Liver Diseases       1  /nkf-dialysis
# 4      horsie63  Metabolic & Endocrine Disorders       2  /nkf-dialysis
# 5      horsie63           Renal & Liver Diseases       2  /nkf-dialysis
# 6      horsie63          Cardiovascular Diseases       1  /nkf-dialysis
# 7  Bassetmommer           Renal & Liver Diseases       2  /nkf-dialysis
# 8  Bassetmommer              Autoimmune Diseases       1  /nkf-dialysis
# 9   Beachgirl32           Renal & Liver Diseases       2  /nkf-dialysis
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\nkf-dialysis_co-occurrence.json
#
# Processing community: /theibsnetwork
#       user                                            cluster  weight  \
# 0     xjrs     Digestive Health (Gastrointestinal Conditions)       2
# 1     xjrs                      Lifestyle, Diet & Supplements       3
# 2     xjrs  Reproductive & Sexual Health (Women's Health &...       1
# 3     xjrs                Mental Health & Emotional Wellbeing       1
# 4  Luisa22     Digestive Health (Gastrointestinal Conditions)       1
# 5  Luisa22                      Lifestyle, Diet & Supplements       2
# 6  Eliana5                Mental Health & Emotional Wellbeing       7
# 7  Eliana5                             Neurological Disorders       1
# 8  Eliana5     Digestive Health (Gastrointestinal Conditions)       3
# 9  Eliana5                  Pain & Musculoskeletal Conditions       2
#
#          comm_url
# 0  /theibsnetwork
# 1  /theibsnetwork
# 2  /theibsnetwork
# 3  /theibsnetwork
# 4  /theibsnetwork
# 5  /theibsnetwork
# 6  /theibsnetwork
# 7  /theibsnetwork
# 8  /theibsnetwork
# 9  /theibsnetwork
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\theibsnetwork_co-occurrence.json
#
# Processing community: /fndhope
#           user                                         cluster  weight  \
# 0   Shimmyaway                          Neurological Disorders       2
# 1   Shimmyaway             Mental Health & Emotional Wellbeing       1
# 2   Shimmyaway                     Patient Support & Education       1
# 3   Shimmyaway                         Cardiovascular Diseases       2
# 4    LEEJUNFAN                          Neurological Disorders       2
# 5    LEEJUNFAN                   Lifestyle, Diet & Supplements       1
# 6     cathys20                             Autoimmune Diseases       1
# ...
# 0  /lupusflorida
# 1  /lupusflorida
# 2  /lupusflorida
# 3  /lupusflorida
# 4  /lupusflorida
# 5  /lupusflorida
# 6  /lupusflorida
# 7  /lupusflorida
# 8  /lupusflorida
# 9  /lupusflorida
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\lupusflorida_co-occurrence.json
#
# Processing community: /quit4life
#                 user                                            cluster  \
# 0            SanJane                      Lifestyle, Diet & Supplements
# 1            SanJane  Reproductive & Sexual Health (Women's Health &...
# 2            SanJane                        Substance Abuse & Addiction
# 3  DifficultyLevel80                        Substance Abuse & Addiction
# 4    Blueunicorn1975                      Lifestyle, Diet & Supplements
# 5    Blueunicorn1975                        Substance Abuse & Addiction
# 6         Dontneedit                      Lifestyle, Diet & Supplements
# 7         Dontneedit                        Substance Abuse & Addiction
# 8    michellesdeli46                      Preventive Health & Screening
# 9     MasterSplinter  Reproductive & Sexual Health (Women's Health &...
#
#    weight    comm_url
# 0       4  /quit4life
# 1       1  /quit4life
# 2       1  /quit4life
# 3       1  /quit4life
# 4       2  /quit4life
# 5       1  /quit4life
# 6       1  /quit4life
# 7       1  /quit4life
# 8       2  /quit4life
# 9       1  /quit4life
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\quit4life_co-occurrence.json
#
# Processing community: /nkf-living-donation
#           user                                            cluster  weight  \
# 0    Rangers78  Reproductive & Sexual Health (Women's Health &...       1
# 1    Rangers78                      Lifestyle, Diet & Supplements       2
# 2    Rangers78                Mental Health & Emotional Wellbeing       1
# 3   Dr_sucheta  Reproductive & Sexual Health (Women's Health &...       2
# 4   Dr_sucheta                      Lifestyle, Diet & Supplements       2
# 5  March-31-09                             Renal & Liver Diseases       1
# 6  March-31-09                Mental Health & Emotional Wellbeing       1
# 7  March-31-09                      Lifestyle, Diet & Supplements       2
# 8  March-31-09  Reproductive & Sexual Health (Women's Health &...       1
# 9       juhi19  Reproductive & Sexual Health (Women's Health &...       3
#
#                comm_url
# 0  /nkf-living-donation
# 1  /nkf-living-donation
# 2  /nkf-living-donation
# 3  /nkf-living-donation
# 4  /nkf-living-donation
# 5  /nkf-living-donation
# 6  /nkf-living-donation
# 7  /nkf-living-donation
# 8  /nkf-living-donation
# 9  /nkf-living-donation
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\nkf-living-donation_co-occurrence.json
#
# Processing community: /cavernoma-uk
#          user                                            cluster  weight  \
# 0        Jeeg                             Neurological Disorders       1
# 1        Jeeg            Procedures, Surgeries & Medical Devices       1
# 2      Trish5                  Pain & Musculoskeletal Conditions       3
# 3      Trish5                            Cardiovascular Diseases       1
# 4      Trish5                             Neurological Disorders       1
# 5  AntonellaS                             Neurological Disorders       1
# 6  AntonellaS                Mental Health & Emotional Wellbeing       1
# 7  AntonellaS                      Lifestyle, Diet & Supplements       2
# 8  AntonellaS  Reproductive & Sexual Health (Women's Health &...       1
# 9      otonal                                  Cancer & Oncology       3
#
#         comm_url
# 0  /cavernoma-uk
# 1  /cavernoma-uk
# 2  /cavernoma-uk
# 3  /cavernoma-uk
# 4  /cavernoma-uk
# 5  /cavernoma-uk
# 6  /cavernoma-uk
# 7  /cavernoma-uk
# 8  /cavernoma-uk
# 9  /cavernoma-uk
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\cavernoma-uk_co-occurrence.json
#
# Processing community: /pcdsupport
#          user                              cluster  weight     comm_url
# 0    fionac66                    Cancer & Oncology       1  /pcdsupport
# 1    fionac66    Rare Diseases & Genetic Disorders       1  /pcdsupport
# 2  Morrison10  Respiratory Conditions & Treatments       3  /pcdsupport
# 3  Morrison10   Infectious & Communicable Diseases       1  /pcdsupport
# 4  Morrison10    Rare Diseases & Genetic Disorders       1  /pcdsupport
# 5  Morrison10   Medications & Treatment Monitoring       1  /pcdsupport
# 6  Morrison10        Lifestyle, Diet & Supplements       3  /pcdsupport
# 7        LD28    Rare Diseases & Genetic Disorders       1  /pcdsupport
# 8     Iram_sa   Infectious & Communicable Diseases       1  /pcdsupport
# 9     Iram_sa  Respiratory Conditions & Treatments       2  /pcdsupport
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\pcdsupport_co-occurrence.json
#
# Processing community: /fpa-contraception
#              user                                            cluster  weight  \
# 0  bummertaken123  Reproductive & Sexual Health (Women's Health &...       1
# 1         Nik3487  Reproductive & Sexual Health (Women's Health &...       2
# 2         Nik3487                        Patient Support & Education       1
# 3        Angels13     Digestive Health (Gastrointestinal Conditions)       1
# 4        Angels13                             Neurological Disorders       1
# 5        Angels13                            Cardiovascular Diseases       1
# 6        Angels13                      Lifestyle, Diet & Supplements       2
# 7        Angels13  Reproductive & Sexual Health (Women's Health &...       1
# 8         Lhdanny                Mental Health & Emotional Wellbeing       1
# 9         Lhdanny                            Cardiovascular Diseases       1
#
#              comm_url
# 0  /fpa-contraception
# 1  /fpa-contraception
# 2  /fpa-contraception
# 3  /fpa-contraception
# 4  /fpa-contraception
# 5  /fpa-contraception
# 6  /fpa-contraception
# 7  /fpa-contraception
# 8  /fpa-contraception
# 9  /fpa-contraception
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\fpa-contraception_co-occurrence.json
#
# Processing community: /opacaregivers
#           user                                         cluster  weight  \
# 0   Food_Drink                               Cancer & Oncology       1
# 1  Notknowmuch  Digestive Health (Gastrointestinal Conditions)       3
# 2  Notknowmuch                               Cancer & Oncology       1
# 3    Redpanda5             Mental Health & Emotional Wellbeing       1
#
#          comm_url
# 0  /opacaregivers
# 1  /opacaregivers
# 2  /opacaregivers
# 3  /opacaregivers
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\opacaregivers_co-occurrence.json
#
# Processing community: /barretts-oesophagus
#               user                                         cluster  weight  \
# 0  Christopher1962                 Metabolic & Endocrine Disorders       1
# 1  Christopher1962               Pain & Musculoskeletal Conditions       1
# 2  Christopher1962  Digestive Health (Gastrointestinal Conditions)       1
# 3  Christopher1962                               Cancer & Oncology       1
# 4       Badger2024               Pain & Musculoskeletal Conditions       1
# 5       Badger2024                   Lifestyle, Diet & Supplements       1
# 6       Badger2024             Mental Health & Emotional Wellbeing       1
# 7       Badger2024                          Renal & Liver Diseases       2
# 8       Badger2024                         Cardiovascular Diseases       1
# 9       Badger2024  Digestive Health (Gastrointestinal Conditions)       1
#
#                comm_url
# 0  /barretts-oesophagus
# 1  /barretts-oesophagus
# 2  /barretts-oesophagus
# 3  /barretts-oesophagus
# 4  /barretts-oesophagus
# 5  /barretts-oesophagus
# 6  /barretts-oesophagus
# 7  /barretts-oesophagus
# 8  /barretts-oesophagus
# 9  /barretts-oesophagus
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\barretts-oesophagus_co-occurrence.json
#
# Processing community: /partnersforbehcets
#           user                                         cluster  weight  \
# 0  TurtleWings               Pain & Musculoskeletal Conditions      15
# 1  TurtleWings                          Neurological Disorders      11
# 2  TurtleWings                   Lifestyle, Diet & Supplements       9
# 3  TurtleWings             Mental Health & Emotional Wellbeing       5
# 4  TurtleWings              Medications & Treatment Monitoring       6
# 5  TurtleWings                             Autoimmune Diseases       3
# 6  TurtleWings  Digestive Health (Gastrointestinal Conditions)       5
# 7  TurtleWings                      Dermatology & Skin-Related       1
# 8  TurtleWings              Infectious & Communicable Diseases       2
# 9  TurtleWings                 Metabolic & Endocrine Disorders       1
#
#               comm_url
# 0  /partnersforbehcets
# 1  /partnersforbehcets
# 2  /partnersforbehcets
# 3  /partnersforbehcets
# 4  /partnersforbehcets
# 5  /partnersforbehcets
# 6  /partnersforbehcets
# 7  /partnersforbehcets
# 8  /partnersforbehcets
# 9  /partnersforbehcets
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\partnersforbehcets_co-occurrence.json
#
# Processing community: /leukodystrophy-support
#          user                                            cluster  weight  \
# 0     SusanBr                             Neurological Disorders       1
# 1     SusanBr                      Lifestyle, Diet & Supplements       2
# 2     SusanBr  Reproductive & Sexual Health (Women's Health &...       1
# 3  SongStream                  Pain & Musculoskeletal Conditions       1
# 4  SongStream                    Metabolic & Endocrine Disorders       2
# 5  SongStream                 Medications & Treatment Monitoring       1
# 6  SongStream                             Neurological Disorders       2
# 7      Kranal                             Neurological Disorders       3
# 8      Kranal                  Pain & Musculoskeletal Conditions       1
# 9      Kranal                      Lifestyle, Diet & Supplements       1
#
#                   comm_url
# 0  /leukodystrophy-support
# 1  /leukodystrophy-support
# 2  /leukodystrophy-support
# 3  /leukodystrophy-support
# 4  /leukodystrophy-support
# 5  /leukodystrophy-support
# 6  /leukodystrophy-support
# 7  /leukodystrophy-support
# 8  /leukodystrophy-support
# 9  /leukodystrophy-support
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\leukodystrophy-support_co-occurrence.json
#
# Processing community: /wombcancersupportuk
#         user                                            cluster  weight  \
# 0    Butekaz                                  Cancer & Oncology       1
# 1  Supermary                                  Cancer & Oncology       3
# 2      diww1                  Pain & Musculoskeletal Conditions       2
# 3      diww1                                Autoimmune Diseases       2
# 4      diww1                            Cardiovascular Diseases       1
# 5      diww1  Reproductive & Sexual Health (Women's Health &...       3
# 6      diww1     Digestive Health (Gastrointestinal Conditions)       3
# 7      diww1                                Eye & Vision Health       1
# 8      Zel64                                  Cancer & Oncology       1
# 9      Zel64  Reproductive & Sexual Health (Women's Health &...       3
#
#                comm_url
# 0  /wombcancersupportuk
# 1  /wombcancersupportuk
# 2  /wombcancersupportuk
# 3  /wombcancersupportuk
# 4  /wombcancersupportuk
# 5  /wombcancersupportuk
# 6  /wombcancersupportuk
# 7  /wombcancersupportuk
# 8  /wombcancersupportuk
# 9  /wombcancersupportuk
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\wombcancersupportuk_co-occurrence.json
#
# Processing community: /melanoma-canada
#               user                                            cluster  weight  \
# 0  nataliemelanoma                                  Cancer & Oncology       4
# 1  nataliemelanoma  Reproductive & Sexual Health (Women's Health &...       1
# 2           Foxy79                Respiratory Conditions & Treatments       2
# 3           Foxy79            Procedures, Surgeries & Medical Devices       1
# 4     katiesho1946                      Lifestyle, Diet & Supplements       1
# 5       PAIrishFan                                  Cancer & Oncology       1
# 6       PAIrishFan            Procedures, Surgeries & Medical Devices       1
# 7       PAIrishFan                      Lifestyle, Diet & Supplements       3
# 8           Liserc                      Lifestyle, Diet & Supplements       2
# 9  vasectomyottawa                      Lifestyle, Diet & Supplements       1
#
#            comm_url
# 0  /melanoma-canada
# 1  /melanoma-canada
# 2  /melanoma-canada
# 3  /melanoma-canada
# 4  /melanoma-canada
# 5  /melanoma-canada
# 6  /melanoma-canada
# 7  /melanoma-canada
# 8  /melanoma-canada
# 9  /melanoma-canada
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\melanoma-canada_co-occurrence.json
#
# Processing community: /myeloma-america-support
#              user                                            cluster  weight  \
# 0    andrewschorr                                  Cancer & Oncology       2
# 1    andrewschorr                                Autoimmune Diseases       1
# 2  2_old_and_grey                                  Cancer & Oncology       1
# 3          AJJ123  Reproductive & Sexual Health (Women's Health &...       1
# 4           Tam13                  Pain & Musculoskeletal Conditions       2
# 5           Tam13     Digestive Health (Gastrointestinal Conditions)       1
# 6           Tam13                                Autoimmune Diseases       1
# 7         RevMan1                                  Cancer & Oncology       3
# 8         anniehb                  Pain & Musculoskeletal Conditions       2
# 9         anniehb                      Lifestyle, Diet & Supplements       2
#
#                    comm_url
# 0  /myeloma-america-support
# 1  /myeloma-america-support
# 2  /myeloma-america-support
# 3  /myeloma-america-support
# 4  /myeloma-america-support
# 5  /myeloma-america-support
# 6  /myeloma-america-support
# 7  /myeloma-america-support
# 8  /myeloma-america-support
# 9  /myeloma-america-support
#
# Projected cluster co-occurrence edges saved to: C:\Users\nastya\thesis\tum-thesis\data\bipartite_network\community-specific_patterns\cluster_co-occurrence_edges_by_comm\myeloma-america-support_co-occurrence.json
#
# Summary:
# Total communities: 325
# Communities with tags: 325
# Communities skipped (no tags): 0
